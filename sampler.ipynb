# %%
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import AGNNConv
from torch_geometric.datasets import Planetoid
from torch_geometric.loader import GraphSAINTRandomWalkSampler, GraphSAINTNodeSampler
from matplotlib import pyplot as plt
import numpy as np
from train_utils import *
from product_graph import *
from torch_geometric.data import HeteroData
from tqdm import tqdm

# %% [markdown]
# #### Load the dataset

# %%
# static_data = np.load("data/preprocessed/static_data.npy", allow_pickle = True)
dynamic_data = torch.tensor(np.load("data/preprocessed/dynamic_data.npy", allow_pickle=True))
S = torch.tensor(np.load("data/adjacency/coords_features.npy", allow_pickle=False))
S.shape
# Out:
# torch.Size([2628, 2628])

# %% [markdown]
# #### Process the data

# %%
data = Data(x = dynamic_data)
edge_index = torch.nonzero(torch.tensor(S), as_tuple=False).t().contiguous()
edge_weight = S[edge_index[0], edge_index[1]]
data.edge_index = edge_index
data.edge_weight = edge_weight
# Out:
# C:\Users\Primakov Chungkham\AppData\Local\Temp\ipykernel_3948\2032024527.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   edge_index = torch.nonzero(torch.tensor(S), as_tuple=False).t().contiguous()

# %%
data
# Out:
# Data(x=[2628, 279], edge_index=[2, 1671876], edge_weight=[1671876])

# %% [markdown]
# #### Sampler method 1: Call create_forecasting_dataset for each subgraphs.

# %%
# Define GraphSAINTRandomWalkSampler
loader = GraphSAINTNodeSampler (
    data,
    batch_size=200,
    num_steps=6,
)

# Example: Iterate over the DataLoader
for i, batch in enumerate(loader):
    dataset = create_forecasting_dataset(batch.x.T,
                                      splits = None,
                                      pred_horizen= 1,
                                      obs_window= 4,
                                      verbose = 0)
    batch_sample = Data(x = torch.tensor(dataset['trn']['data']), y = torch.tensor(dataset['trn']['labels']), 
                        edge_index= batch.edge_index, edge_weight = batch.edge_weight)
    print(f"Batch {i+1}: {batch_sample}")
# Out:
# Batch 1: Data(x=[275, 189, 4], edge_index=[2, 13246], y=[275, 189, 1], edge_weight=[13246])
# Batch 2: Data(x=[275, 192, 4], edge_index=[2, 13166], y=[275, 192, 1], edge_weight=[13166])
# Batch 3: Data(x=[275, 192, 4], edge_index=[2, 14350], y=[275, 192, 1], edge_weight=[14350])
# Batch 4: Data(x=[275, 186, 4], edge_index=[2, 14248], y=[275, 186, 1], edge_weight=[14248])
# Batch 5: Data(x=[275, 193, 4], edge_index=[2, 14626], y=[275, 193, 1], edge_weight=[14626])
# Batch 6: Data(x=[275, 191, 4], edge_index=[2, 14054], y=[275, 191, 1], edge_weight=[14054])

# %% [markdown]
# #### Sampler method 2: Call try nested loader method.

# %% [markdown]
# 1. First loop through the samples (the time samples)
# 2. For each samplee graph, build subgraph and train with them
# 3. With this method, we can have train test split along the sample dimension

# %%
data = create_forecasting_dataset(dynamic_data.T,
                                      splits = [0.8, 0.1, 0.1],
                                      pred_horizen= 1,
                                      obs_window= 4,
                                      verbose = 0)
edge_index = torch.nonzero(torch.tensor(S), as_tuple=False).t().contiguous()
edge_weight = S[edge_index[0], edge_index[1]]
# Out:
# C:\Users\Primakov Chungkham\AppData\Local\Temp\ipykernel_3948\2291733252.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   edge_index = torch.nonzero(torch.tensor(S), as_tuple=False).t().contiguous()

# %% [markdown]
# #### For training set

# %%
# loop over the number of samples
num_samples = data['trn']['data'].shape[0]
for i in range(num_samples):
    print(f"outer batch {i}")
    # Create a torch geometric data over each graph 
    outer_batch = Data(x = torch.tensor(data['trn']['data'][i]), y = torch.tensor(data['trn']['labels'][i].squeeze()),
                       edge_index=edge_index, edge_weight = edge_weight) 
    
    loader = GraphSAINTNodeSampler(outer_batch, batch_size=100, num_steps=6)
    for inner_batch in loader:
        print(inner_batch)
# Out:
# outer batch 0
# Data(num_nodes=98, edge_index=[2, 3992], x=[98, 4], y=[98], edge_weight=[3992])
# Data(num_nodes=97, edge_index=[2, 3782], x=[97, 4], y=[97], edge_weight=[3782])
# Data(num_nodes=98, edge_index=[2, 3686], x=[98, 4], y=[98], edge_weight=[3686])
# Data(num_nodes=97, edge_index=[2, 3564], x=[97, 4], y=[97], edge_weight=[3564])
# Data(num_nodes=99, edge_index=[2, 3538], x=[99, 4], y=[99], edge_weight=[3538])
# Data(num_nodes=99, edge_index=[2, 3640], x=[99, 4], y=[99], edge_weight=[3640])
# outer batch 1
# Data(num_nodes=98, edge_index=[2, 3520], x=[98, 4], y=[98], edge_weight=[3520])
# Data(num_nodes=96, edge_index=[2, 3816], x=[96, 4], y=[96], edge_weight=[3816])
# Data(num_nodes=99, edge_index=[2, 3420], x=[99, 4], y=[99], edge_weight=[3420])
# Data(num_nodes=98, edge_index=[2, 3800], x=[98, 4], y=[98], edge_weight=[3800])
# Data(num_nodes=98, edge_index=[2, 3508], x=[98, 4], y=[98], edge_weight=[3508])
# Data(num_nodes=96, edge_index=[2, 3594], x=[96, 4], y=[96], edge_weight=[3594])
# outer batch 2
# Data(num_nodes=98, edge_index=[2, 3420], x=[98, 4], y=[98], edge_weight=[3420])
# Data(num_nodes=96, edge_index=[2, 3824], x=[96, 4], y=[96], edge_weight=[3824])
# Data(num_nodes=96, edge_index=[2, 3504], x=[96, 4], y=[96], edge_weight=[3504])
# Data(num_nodes=99, edge_index=[2, 4172], x=[99, 4], y=[99], edge_weight=[4172])
# Data(num_nodes=99, edge_index=[2, 4316], x=[99, 4], y=[99], edge_weight=[4316])
# Data(num_nodes=96, edge_index=[2, 3784], x=[96, 4], y=[96], edge_weight=[3784])
# outer batch 3
# Data(num_nodes=96, edge_index=[2, 3380], x=[96, 4], y=[96], edge_weight=[3380])
# Data(num_nodes=97, edge_index=[2, 3572], x=[97, 4], y=[97], edge_weight=[3572])
# Data(num_nodes=96, edge_index=[2, 3108], x=[96, 4], y=[96], edge_weight=[3108])
# Data(num_nodes=96, edge_index=[2, 3592], x=[96, 4], y=[96], edge_weight=[3592])
# Data(num_nodes=97, edge_index=[2, 3522], x=[97, 4], y=[97], edge_weight=[3522])
# Data(num_nodes=98, edge_index=[2, 3780], x=[98, 4], y=[98], edge_weight=[3780])
# outer batch 4
# Data(num_nodes=99, edge_index=[2, 3838], x=[99, 4], y=[99], edge_weight=[3838])
# Data(num_nodes=96, edge_index=[2, 3892], x=[96, 4], y=[96], edge_weight=[3892])
# Data(num_nodes=96, edge_index=[2, 3562], x=[96, 4], y=[96], edge_weight=[3562])
# Data(num_nodes=97, edge_index=[2, 3200], x=[97, 4], y=[97], edge_weight=[3200])
# Data(num_nodes=97, edge_index=[2, 3464], x=[97, 4], y=[97], edge_weight=[3464])
# Data(num_nodes=97, edge_index=[2, 3072], x=[97, 4], y=[97], edge_weight=[3072])
# outer batch 5
# Data(num_nodes=96, edge_index=[2, 3620], x=[96, 4], y=[96], edge_weight=[3620])
# Data(num_nodes=96, edge_index=[2, 3816], x=[96, 4], y=[96], edge_weight=[3816])
# Data(num_nodes=96, edge_index=[2, 3696], x=[96, 4], y=[96], edge_weight=[3696])
# Data(num_nodes=98, edge_index=[2, 3762], x=[98, 4], y=[98], edge_weight=[3762])
# Data(num_nodes=99, edge_index=[2, 3738], x=[99, 4], y=[99], edge_weight=[3738])
# Data(num_nodes=98, edge_index=[2, 4178], x=[98, 4], y=[98], edge_weight=[4178])
# outer batch 6
# Data(num_nodes=98, edge_index=[2, 3684], x=[98, 4], y=[98], edge_weight=[3684])
# Data(num_nodes=99, edge_index=[2, 4126], x=[99, 4], y=[99], edge_weight=[4126])
# Data(num_nodes=98, edge_index=[2, 2936], x=[98, 4], y=[98], edge_weight=[2936])
# Data(num_nodes=97, edge_index=[2, 4714], x=[97, 4], y=[97], edge_weight=[4714])
# Data(num_nodes=98, edge_index=[2, 3984], x=[98, 4], y=[98], edge_weight=[3984])
# Data(num_nodes=97, edge_index=[2, 3798], x=[97, 4], y=[97], edge_weight=[3798])
# outer batch 7
# Data(num_nodes=98, edge_index=[2, 3536], x=[98, 4], y=[98], edge_weight=[3536])
# Data(num_nodes=99, edge_index=[2, 3644], x=[99, 4], y=[99], edge_weight=[3644])
# Data(num_nodes=99, edge_index=[2, 3150], x=[99, 4], y=[99], edge_weight=[3150])
# Data(num_nodes=99, edge_index=[2, 3260], x=[99, 4], y=[99], edge_weight=[3260])
# Data(num_nodes=98, edge_index=[2, 3894], x=[98, 4], y=[98], edge_weight=[3894])
# Data(num_nodes=100, edge_index=[2, 4066], x=[100, 4], y=[100], edge_weight=[4066])
# outer batch 8
# Data(num_nodes=97, edge_index=[2, 3682], x=[97, 4], y=[97], edge_weight=[3682])
# Data(num_nodes=96, edge_index=[2, 3858], x=[96, 4], y=[96], edge_weight=[3858])
# Data(num_nodes=99, edge_index=[2, 3882], x=[99, 4], y=[99], edge_weight=[3882])
# Data(num_nodes=96, edge_index=[2, 3738], x=[96, 4], y=[96], edge_weight=[3738])
# Data(num_nodes=97, edge_index=[2, 3746], x=[97, 4], y=[97], edge_weight=[3746])
# Data(num_nodes=99, edge_index=[2, 4718], x=[99, 4], y=[99], edge_weight=[4718])
# outer batch 9
# Data(num_nodes=97, edge_index=[2, 3182], x=[97, 4], y=[97], edge_weight=[3182])
# Data(num_nodes=95, edge_index=[2, 3770], x=[95, 4], y=[95], edge_weight=[3770])
# Data(num_nodes=95, edge_index=[2, 3444], x=[95, 4], y=[95], edge_weight=[3444])
# Data(num_nodes=97, edge_index=[2, 3834], x=[97, 4], y=[97], edge_weight=[3834])
# Data(num_nodes=96, edge_index=[2, 3890], x=[96, 4], y=[96], edge_weight=[3890])
# Data(num_nodes=93, edge_index=[2, 3130], x=[93, 4], y=[93], edge_weight=[3130])
# outer batch 10
# Data(num_nodes=98, edge_index=[2, 4166], x=[98, 4], y=[98], edge_weight=[4166])
# Data(num_nodes=98, edge_index=[2, 3654], x=[98, 4], y=[98], edge_weight=[3654])
# Data(num_nodes=99, edge_index=[2, 3658], x=[99, 4], y=[99], edge_weight=[3658])
# Data(num_nodes=99, edge_index=[2, 4016], x=[99, 4], y=[99], edge_weight=[4016])
# Data(num_nodes=97, edge_index=[2, 4130], x=[97, 4], y=[97], edge_weight=[4130])
# Data(num_nodes=98, edge_index=[2, 3522], x=[98, 4], y=[98], edge_weight=[3522])
# outer batch 11
# Data(num_nodes=98, edge_index=[2, 3750], x=[98, 4], y=[98], edge_weight=[3750])
# Data(num_nodes=99, edge_index=[2, 3888], x=[99, 4], y=[99], edge_weight=[3888])
# Data(num_nodes=98, edge_index=[2, 3794], x=[98, 4], y=[98], edge_weight=[3794])
# Data(num_nodes=96, edge_index=[2, 4064], x=[96, 4], y=[96], edge_weight=[4064])
# Data(num_nodes=99, edge_index=[2, 3694], x=[99, 4], y=[99], edge_weight=[3694])
# Data(num_nodes=99, edge_index=[2, 3776], x=[99, 4], y=[99], edge_weight=[3776])
# outer batch 12
# Data(num_nodes=99, edge_index=[2, 4364], x=[99, 4], y=[99], edge_weight=[4364])
# Data(num_nodes=98, edge_index=[2, 3954], x=[98, 4], y=[98], edge_weight=[3954])
# Data(num_nodes=99, edge_index=[2, 4194], x=[99, 4], y=[99], edge_weight=[4194])
# Data(num_nodes=98, edge_index=[2, 3994], x=[98, 4], y=[98], edge_weight=[3994])
# Data(num_nodes=98, edge_index=[2, 4048], x=[98, 4], y=[98], edge_weight=[4048])
# Data(num_nodes=98, edge_index=[2, 3836], x=[98, 4], y=[98], edge_weight=[3836])
# outer batch 13
# Data(num_nodes=98, edge_index=[2, 4146], x=[98, 4], y=[98], edge_weight=[4146])
# Data(num_nodes=97, edge_index=[2, 3774], x=[97, 4], y=[97], edge_weight=[3774])
# Data(num_nodes=97, edge_index=[2, 3442], x=[97, 4], y=[97], edge_weight=[3442])
# Data(num_nodes=98, edge_index=[2, 3702], x=[98, 4], y=[98], edge_weight=[3702])
# Data(num_nodes=98, edge_index=[2, 3486], x=[98, 4], y=[98], edge_weight=[3486])
# Data(num_nodes=99, edge_index=[2, 3876], x=[99, 4], y=[99], edge_weight=[3876])
# outer batch 14
# Data(num_nodes=98, edge_index=[2, 3438], x=[98, 4], y=[98], edge_weight=[3438])
# Data(num_nodes=100, edge_index=[2, 3692], x=[100, 4], y=[100], edge_weight=[3692])
# Data(num_nodes=99, edge_index=[2, 3554], x=[99, 4], y=[99], edge_weight=[3554])
# Data(num_nodes=96, edge_index=[2, 3462], x=[96, 4], y=[96], edge_weight=[3462])
# Data(num_nodes=98, edge_index=[2, 3368], x=[98, 4], y=[98], edge_weight=[3368])
# Data(num_nodes=96, edge_index=[2, 3298], x=[96, 4], y=[96], edge_weight=[3298])
# outer batch 15
# Data(num_nodes=99, edge_index=[2, 3720], x=[99, 4], y=[99], edge_weight=[3720])
# Data(num_nodes=98, edge_index=[2, 4010], x=[98, 4], y=[98], edge_weight=[4010])
# Data(num_nodes=98, edge_index=[2, 3978], x=[98, 4], y=[98], edge_weight=[3978])
# Data(num_nodes=99, edge_index=[2, 3272], x=[99, 4], y=[99], edge_weight=[3272])
# Data(num_nodes=99, edge_index=[2, 4242], x=[99, 4], y=[99], edge_weight=[4242])
# Data(num_nodes=97, edge_index=[2, 3674], x=[97, 4], y=[97], edge_weight=[3674])
# outer batch 16
# Data(num_nodes=97, edge_index=[2, 3748], x=[97, 4], y=[97], edge_weight=[3748])
# Data(num_nodes=99, edge_index=[2, 3396], x=[99, 4], y=[99], edge_weight=[3396])
# Data(num_nodes=97, edge_index=[2, 3620], x=[97, 4], y=[97], edge_weight=[3620])
# Data(num_nodes=99, edge_index=[2, 3572], x=[99, 4], y=[99], edge_weight=[3572])
# Data(num_nodes=97, edge_index=[2, 3536], x=[97, 4], y=[97], edge_weight=[3536])
# Data(num_nodes=95, edge_index=[2, 3998], x=[95, 4], y=[95], edge_weight=[3998])
# outer batch 17
# Data(num_nodes=96, edge_index=[2, 3062], x=[96, 4], y=[96], edge_weight=[3062])
# Data(num_nodes=97, edge_index=[2, 4044], x=[97, 4], y=[97], edge_weight=[4044])
# Data(num_nodes=95, edge_index=[2, 3290], x=[95, 4], y=[95], edge_weight=[3290])
# Data(num_nodes=97, edge_index=[2, 3848], x=[97, 4], y=[97], edge_weight=[3848])
# Data(num_nodes=96, edge_index=[2, 4468], x=[96, 4], y=[96], edge_weight=[4468])
# Data(num_nodes=98, edge_index=[2, 3426], x=[98, 4], y=[98], edge_weight=[3426])
# outer batch 18
# Data(num_nodes=96, edge_index=[2, 3406], x=[96, 4], y=[96], edge_weight=[3406])
# Data(num_nodes=97, edge_index=[2, 3754], x=[97, 4], y=[97], edge_weight=[3754])
# Data(num_nodes=99, edge_index=[2, 3710], x=[99, 4], y=[99], edge_weight=[3710])
# Data(num_nodes=96, edge_index=[2, 3162], x=[96, 4], y=[96], edge_weight=[3162])
# Data(num_nodes=96, edge_index=[2, 3654], x=[96, 4], y=[96], edge_weight=[3654])
# Data(num_nodes=97, edge_index=[2, 3832], x=[97, 4], y=[97], edge_weight=[3832])
# outer batch 19
# Data(num_nodes=98, edge_index=[2, 3268], x=[98, 4], y=[98], edge_weight=[3268])
# Data(num_nodes=99, edge_index=[2, 3938], x=[99, 4], y=[99], edge_weight=[3938])
# Data(num_nodes=98, edge_index=[2, 2862], x=[98, 4], y=[98], edge_weight=[2862])
# Data(num_nodes=99, edge_index=[2, 3742], x=[99, 4], y=[99], edge_weight=[3742])
# Data(num_nodes=97, edge_index=[2, 3712], x=[97, 4], y=[97], edge_weight=[3712])
# Data(num_nodes=96, edge_index=[2, 4150], x=[96, 4], y=[96], edge_weight=[4150])
# outer batch 20
# Data(num_nodes=97, edge_index=[2, 3486], x=[97, 4], y=[97], edge_weight=[3486])
# Data(num_nodes=100, edge_index=[2, 3842], x=[100, 4], y=[100], edge_weight=[3842])
# Data(num_nodes=99, edge_index=[2, 3410], x=[99, 4], y=[99], edge_weight=[3410])
# Data(num_nodes=98, edge_index=[2, 4134], x=[98, 4], y=[98], edge_weight=[4134])
# Data(num_nodes=98, edge_index=[2, 3602], x=[98, 4], y=[98], edge_weight=[3602])
# Data(num_nodes=99, edge_index=[2, 3276], x=[99, 4], y=[99], edge_weight=[3276])
# outer batch 21
# Data(num_nodes=96, edge_index=[2, 3734], x=[96, 4], y=[96], edge_weight=[3734])
# Data(num_nodes=100, edge_index=[2, 4344], x=[100, 4], y=[100], edge_weight=[4344])
# Data(num_nodes=96, edge_index=[2, 3538], x=[96, 4], y=[96], edge_weight=[3538])
# Data(num_nodes=97, edge_index=[2, 3270], x=[97, 4], y=[97], edge_weight=[3270])
# Data(num_nodes=98, edge_index=[2, 3716], x=[98, 4], y=[98], edge_weight=[3716])
# Data(num_nodes=99, edge_index=[2, 3826], x=[99, 4], y=[99], edge_weight=[3826])
# outer batch 22
# Data(num_nodes=96, edge_index=[2, 3418], x=[96, 4], y=[96], edge_weight=[3418])
# Data(num_nodes=96, edge_index=[2, 3650], x=[96, 4], y=[96], edge_weight=[3650])
# Data(num_nodes=95, edge_index=[2, 3516], x=[95, 4], y=[95], edge_weight=[3516])
# Data(num_nodes=96, edge_index=[2, 3336], x=[96, 4], y=[96], edge_weight=[3336])
# Data(num_nodes=99, edge_index=[2, 3614], x=[99, 4], y=[99], edge_weight=[3614])
# Data(num_nodes=99, edge_index=[2, 4212], x=[99, 4], y=[99], edge_weight=[4212])
# outer batch 23
# Data(num_nodes=98, edge_index=[2, 3496], x=[98, 4], y=[98], edge_weight=[3496])
# Data(num_nodes=98, edge_index=[2, 4508], x=[98, 4], y=[98], edge_weight=[4508])
# Data(num_nodes=99, edge_index=[2, 3868], x=[99, 4], y=[99], edge_weight=[3868])
# Data(num_nodes=97, edge_index=[2, 4398], x=[97, 4], y=[97], edge_weight=[4398])
# Data(num_nodes=97, edge_index=[2, 4322], x=[97, 4], y=[97], edge_weight=[4322])
# Data(num_nodes=99, edge_index=[2, 3972], x=[99, 4], y=[99], edge_weight=[3972])
# outer batch 24
# Data(num_nodes=99, edge_index=[2, 3738], x=[99, 4], y=[99], edge_weight=[3738])
# Data(num_nodes=99, edge_index=[2, 3364], x=[99, 4], y=[99], edge_weight=[3364])
# Data(num_nodes=98, edge_index=[2, 3692], x=[98, 4], y=[98], edge_weight=[3692])
# Data(num_nodes=100, edge_index=[2, 3412], x=[100, 4], y=[100], edge_weight=[3412])
# Data(num_nodes=97, edge_index=[2, 3832], x=[97, 4], y=[97], edge_weight=[3832])
# Data(num_nodes=100, edge_index=[2, 3800], x=[100, 4], y=[100], edge_weight=[3800])
# outer batch 25
# Data(num_nodes=97, edge_index=[2, 3720], x=[97, 4], y=[97], edge_weight=[3720])
# Data(num_nodes=96, edge_index=[2, 3954], x=[96, 4], y=[96], edge_weight=[3954])
# Data(num_nodes=97, edge_index=[2, 4180], x=[97, 4], y=[97], edge_weight=[4180])
# Data(num_nodes=100, edge_index=[2, 4496], x=[100, 4], y=[100], edge_weight=[4496])
# Data(num_nodes=97, edge_index=[2, 3816], x=[97, 4], y=[97], edge_weight=[3816])
# Data(num_nodes=100, edge_index=[2, 4134], x=[100, 4], y=[100], edge_weight=[4134])
# outer batch 26
# Data(num_nodes=97, edge_index=[2, 3464], x=[97, 4], y=[97], edge_weight=[3464])
# Data(num_nodes=98, edge_index=[2, 3508], x=[98, 4], y=[98], edge_weight=[3508])
# Data(num_nodes=99, edge_index=[2, 4040], x=[99, 4], y=[99], edge_weight=[4040])
# Data(num_nodes=99, edge_index=[2, 3796], x=[99, 4], y=[99], edge_weight=[3796])
# Data(num_nodes=97, edge_index=[2, 4116], x=[97, 4], y=[97], edge_weight=[4116])
# Data(num_nodes=97, edge_index=[2, 3162], x=[97, 4], y=[97], edge_weight=[3162])
# outer batch 27
# Data(num_nodes=98, edge_index=[2, 3872], x=[98, 4], y=[98], edge_weight=[3872])
# Data(num_nodes=97, edge_index=[2, 4068], x=[97, 4], y=[97], edge_weight=[4068])
# Data(num_nodes=96, edge_index=[2, 3340], x=[96, 4], y=[96], edge_weight=[3340])
# Data(num_nodes=94, edge_index=[2, 3852], x=[94, 4], y=[94], edge_weight=[3852])
# Data(num_nodes=99, edge_index=[2, 4052], x=[99, 4], y=[99], edge_weight=[4052])
# Data(num_nodes=97, edge_index=[2, 3856], x=[97, 4], y=[97], edge_weight=[3856])
# outer batch 28
# Data(num_nodes=99, edge_index=[2, 3826], x=[99, 4], y=[99], edge_weight=[3826])
# Data(num_nodes=96, edge_index=[2, 2982], x=[96, 4], y=[96], edge_weight=[2982])
# Data(num_nodes=97, edge_index=[2, 3950], x=[97, 4], y=[97], edge_weight=[3950])
# Data(num_nodes=99, edge_index=[2, 3420], x=[99, 4], y=[99], edge_weight=[3420])
# Data(num_nodes=97, edge_index=[2, 3350], x=[97, 4], y=[97], edge_weight=[3350])
# Data(num_nodes=99, edge_index=[2, 3580], x=[99, 4], y=[99], edge_weight=[3580])
# outer batch 29
# Data(num_nodes=96, edge_index=[2, 3538], x=[96, 4], y=[96], edge_weight=[3538])
# Data(num_nodes=99, edge_index=[2, 4110], x=[99, 4], y=[99], edge_weight=[4110])
# Data(num_nodes=98, edge_index=[2, 3718], x=[98, 4], y=[98], edge_weight=[3718])
# Data(num_nodes=98, edge_index=[2, 3784], x=[98, 4], y=[98], edge_weight=[3784])
# Data(num_nodes=98, edge_index=[2, 4104], x=[98, 4], y=[98], edge_weight=[4104])
# Data(num_nodes=94, edge_index=[2, 3714], x=[94, 4], y=[94], edge_weight=[3714])
# outer batch 30
# Data(num_nodes=98, edge_index=[2, 3470], x=[98, 4], y=[98], edge_weight=[3470])
# Data(num_nodes=99, edge_index=[2, 3558], x=[99, 4], y=[99], edge_weight=[3558])
# Data(num_nodes=95, edge_index=[2, 4070], x=[95, 4], y=[95], edge_weight=[4070])
# Data(num_nodes=99, edge_index=[2, 3326], x=[99, 4], y=[99], edge_weight=[3326])
# Data(num_nodes=97, edge_index=[2, 3734], x=[97, 4], y=[97], edge_weight=[3734])
# Data(num_nodes=96, edge_index=[2, 3312], x=[96, 4], y=[96], edge_weight=[3312])
# outer batch 31
# Data(num_nodes=98, edge_index=[2, 3302], x=[98, 4], y=[98], edge_weight=[3302])
# Data(num_nodes=93, edge_index=[2, 3578], x=[93, 4], y=[93], edge_weight=[3578])
# Data(num_nodes=98, edge_index=[2, 3786], x=[98, 4], y=[98], edge_weight=[3786])
# Data(num_nodes=99, edge_index=[2, 3714], x=[99, 4], y=[99], edge_weight=[3714])
# Data(num_nodes=98, edge_index=[2, 3872], x=[98, 4], y=[98], edge_weight=[3872])
# Data(num_nodes=96, edge_index=[2, 3234], x=[96, 4], y=[96], edge_weight=[3234])
# outer batch 32
# Data(num_nodes=93, edge_index=[2, 3496], x=[93, 4], y=[93], edge_weight=[3496])
# Data(num_nodes=96, edge_index=[2, 3046], x=[96, 4], y=[96], edge_weight=[3046])
# Data(num_nodes=97, edge_index=[2, 3514], x=[97, 4], y=[97], edge_weight=[3514])
# Data(num_nodes=98, edge_index=[2, 3104], x=[98, 4], y=[98], edge_weight=[3104])
# Data(num_nodes=97, edge_index=[2, 3610], x=[97, 4], y=[97], edge_weight=[3610])
# Data(num_nodes=97, edge_index=[2, 3590], x=[97, 4], y=[97], edge_weight=[3590])
# outer batch 33
# Data(num_nodes=100, edge_index=[2, 4310], x=[100, 4], y=[100], edge_weight=[4310])
# Data(num_nodes=98, edge_index=[2, 3592], x=[98, 4], y=[98], edge_weight=[3592])
# Data(num_nodes=97, edge_index=[2, 3970], x=[97, 4], y=[97], edge_weight=[3970])
# Data(num_nodes=99, edge_index=[2, 3862], x=[99, 4], y=[99], edge_weight=[3862])
# Data(num_nodes=96, edge_index=[2, 3048], x=[96, 4], y=[96], edge_weight=[3048])
# Data(num_nodes=97, edge_index=[2, 3576], x=[97, 4], y=[97], edge_weight=[3576])
# outer batch 34
# Data(num_nodes=98, edge_index=[2, 4026], x=[98, 4], y=[98], edge_weight=[4026])
# Data(num_nodes=97, edge_index=[2, 3572], x=[97, 4], y=[97], edge_weight=[3572])
# Data(num_nodes=97, edge_index=[2, 3462], x=[97, 4], y=[97], edge_weight=[3462])
# Data(num_nodes=98, edge_index=[2, 3702], x=[98, 4], y=[98], edge_weight=[3702])
# Data(num_nodes=99, edge_index=[2, 3894], x=[99, 4], y=[99], edge_weight=[3894])
# Data(num_nodes=99, edge_index=[2, 3762], x=[99, 4], y=[99], edge_weight=[3762])
# outer batch 35
# Data(num_nodes=94, edge_index=[2, 3772], x=[94, 4], y=[94], edge_weight=[3772])
# Data(num_nodes=96, edge_index=[2, 3686], x=[96, 4], y=[96], edge_weight=[3686])
# Data(num_nodes=99, edge_index=[2, 4368], x=[99, 4], y=[99], edge_weight=[4368])
# Data(num_nodes=98, edge_index=[2, 3474], x=[98, 4], y=[98], edge_weight=[3474])
# Data(num_nodes=98, edge_index=[2, 4000], x=[98, 4], y=[98], edge_weight=[4000])
# Data(num_nodes=98, edge_index=[2, 4184], x=[98, 4], y=[98], edge_weight=[4184])
# outer batch 36
# Data(num_nodes=97, edge_index=[2, 3474], x=[97, 4], y=[97], edge_weight=[3474])
# Data(num_nodes=99, edge_index=[2, 3488], x=[99, 4], y=[99], edge_weight=[3488])
# Data(num_nodes=98, edge_index=[2, 3924], x=[98, 4], y=[98], edge_weight=[3924])
# Data(num_nodes=97, edge_index=[2, 3214], x=[97, 4], y=[97], edge_weight=[3214])
# Data(num_nodes=99, edge_index=[2, 3510], x=[99, 4], y=[99], edge_weight=[3510])
# Data(num_nodes=99, edge_index=[2, 3350], x=[99, 4], y=[99], edge_weight=[3350])
# outer batch 37
# Data(num_nodes=99, edge_index=[2, 3486], x=[99, 4], y=[99], edge_weight=[3486])
# Data(num_nodes=99, edge_index=[2, 2906], x=[99, 4], y=[99], edge_weight=[2906])
# Data(num_nodes=97, edge_index=[2, 3990], x=[97, 4], y=[97], edge_weight=[3990])
# Data(num_nodes=98, edge_index=[2, 4246], x=[98, 4], y=[98], edge_weight=[4246])
# Data(num_nodes=99, edge_index=[2, 3994], x=[99, 4], y=[99], edge_weight=[3994])
# Data(num_nodes=97, edge_index=[2, 3956], x=[97, 4], y=[97], edge_weight=[3956])
# outer batch 38
# Data(num_nodes=99, edge_index=[2, 3358], x=[99, 4], y=[99], edge_weight=[3358])
# Data(num_nodes=99, edge_index=[2, 3972], x=[99, 4], y=[99], edge_weight=[3972])
# Data(num_nodes=99, edge_index=[2, 3316], x=[99, 4], y=[99], edge_weight=[3316])
# Data(num_nodes=97, edge_index=[2, 3220], x=[97, 4], y=[97], edge_weight=[3220])
# Data(num_nodes=96, edge_index=[2, 3416], x=[96, 4], y=[96], edge_weight=[3416])
# Data(num_nodes=97, edge_index=[2, 3552], x=[97, 4], y=[97], edge_weight=[3552])
# outer batch 39
# Data(num_nodes=97, edge_index=[2, 3306], x=[97, 4], y=[97], edge_weight=[3306])
# Data(num_nodes=97, edge_index=[2, 3382], x=[97, 4], y=[97], edge_weight=[3382])
# Data(num_nodes=98, edge_index=[2, 3378], x=[98, 4], y=[98], edge_weight=[3378])
# Data(num_nodes=98, edge_index=[2, 3904], x=[98, 4], y=[98], edge_weight=[3904])
# Data(num_nodes=95, edge_index=[2, 3378], x=[95, 4], y=[95], edge_weight=[3378])
# Data(num_nodes=100, edge_index=[2, 3276], x=[100, 4], y=[100], edge_weight=[3276])
# outer batch 40
# Data(num_nodes=100, edge_index=[2, 3474], x=[100, 4], y=[100], edge_weight=[3474])
# Data(num_nodes=97, edge_index=[2, 4050], x=[97, 4], y=[97], edge_weight=[4050])
# Data(num_nodes=98, edge_index=[2, 4464], x=[98, 4], y=[98], edge_weight=[4464])
# Data(num_nodes=99, edge_index=[2, 3764], x=[99, 4], y=[99], edge_weight=[3764])
# Data(num_nodes=97, edge_index=[2, 3960], x=[97, 4], y=[97], edge_weight=[3960])
# Data(num_nodes=98, edge_index=[2, 3544], x=[98, 4], y=[98], edge_weight=[3544])
# outer batch 41
# Data(num_nodes=94, edge_index=[2, 3128], x=[94, 4], y=[94], edge_weight=[3128])
# Data(num_nodes=96, edge_index=[2, 3908], x=[96, 4], y=[96], edge_weight=[3908])
# Data(num_nodes=99, edge_index=[2, 4220], x=[99, 4], y=[99], edge_weight=[4220])
# Data(num_nodes=98, edge_index=[2, 4192], x=[98, 4], y=[98], edge_weight=[4192])
# Data(num_nodes=96, edge_index=[2, 3762], x=[96, 4], y=[96], edge_weight=[3762])
# Data(num_nodes=98, edge_index=[2, 4072], x=[98, 4], y=[98], edge_weight=[4072])
# outer batch 42
# Data(num_nodes=99, edge_index=[2, 4216], x=[99, 4], y=[99], edge_weight=[4216])
# Data(num_nodes=98, edge_index=[2, 3742], x=[98, 4], y=[98], edge_weight=[3742])
# Data(num_nodes=99, edge_index=[2, 3760], x=[99, 4], y=[99], edge_weight=[3760])
# Data(num_nodes=98, edge_index=[2, 3450], x=[98, 4], y=[98], edge_weight=[3450])
# Data(num_nodes=95, edge_index=[2, 3370], x=[95, 4], y=[95], edge_weight=[3370])
# Data(num_nodes=96, edge_index=[2, 3650], x=[96, 4], y=[96], edge_weight=[3650])
# outer batch 43
# Data(num_nodes=99, edge_index=[2, 3526], x=[99, 4], y=[99], edge_weight=[3526])
# Data(num_nodes=98, edge_index=[2, 4774], x=[98, 4], y=[98], edge_weight=[4774])
# Data(num_nodes=99, edge_index=[2, 3606], x=[99, 4], y=[99], edge_weight=[3606])
# Data(num_nodes=98, edge_index=[2, 3390], x=[98, 4], y=[98], edge_weight=[3390])
# Data(num_nodes=98, edge_index=[2, 3112], x=[98, 4], y=[98], edge_weight=[3112])
# Data(num_nodes=96, edge_index=[2, 3264], x=[96, 4], y=[96], edge_weight=[3264])
# outer batch 44
# Data(num_nodes=97, edge_index=[2, 3548], x=[97, 4], y=[97], edge_weight=[3548])
# Data(num_nodes=99, edge_index=[2, 3326], x=[99, 4], y=[99], edge_weight=[3326])
# Data(num_nodes=97, edge_index=[2, 3358], x=[97, 4], y=[97], edge_weight=[3358])
# Data(num_nodes=98, edge_index=[2, 3950], x=[98, 4], y=[98], edge_weight=[3950])
# Data(num_nodes=99, edge_index=[2, 3546], x=[99, 4], y=[99], edge_weight=[3546])
# Data(num_nodes=97, edge_index=[2, 3790], x=[97, 4], y=[97], edge_weight=[3790])
# outer batch 45
# Data(num_nodes=98, edge_index=[2, 3906], x=[98, 4], y=[98], edge_weight=[3906])
# Data(num_nodes=95, edge_index=[2, 3420], x=[95, 4], y=[95], edge_weight=[3420])
# Data(num_nodes=93, edge_index=[2, 2962], x=[93, 4], y=[93], edge_weight=[2962])
# Data(num_nodes=97, edge_index=[2, 3426], x=[97, 4], y=[97], edge_weight=[3426])
# Data(num_nodes=97, edge_index=[2, 3362], x=[97, 4], y=[97], edge_weight=[3362])
# Data(num_nodes=99, edge_index=[2, 4194], x=[99, 4], y=[99], edge_weight=[4194])
# outer batch 46
# Data(num_nodes=97, edge_index=[2, 3960], x=[97, 4], y=[97], edge_weight=[3960])
# Data(num_nodes=98, edge_index=[2, 3610], x=[98, 4], y=[98], edge_weight=[3610])
# Data(num_nodes=96, edge_index=[2, 3770], x=[96, 4], y=[96], edge_weight=[3770])
# Data(num_nodes=97, edge_index=[2, 3360], x=[97, 4], y=[97], edge_weight=[3360])
# Data(num_nodes=97, edge_index=[2, 4040], x=[97, 4], y=[97], edge_weight=[4040])
# Data(num_nodes=97, edge_index=[2, 3718], x=[97, 4], y=[97], edge_weight=[3718])
# outer batch 47
# Data(num_nodes=95, edge_index=[2, 3656], x=[95, 4], y=[95], edge_weight=[3656])
# Data(num_nodes=99, edge_index=[2, 3346], x=[99, 4], y=[99], edge_weight=[3346])
# Data(num_nodes=98, edge_index=[2, 3762], x=[98, 4], y=[98], edge_weight=[3762])
# Data(num_nodes=98, edge_index=[2, 3388], x=[98, 4], y=[98], edge_weight=[3388])
# Data(num_nodes=97, edge_index=[2, 4322], x=[97, 4], y=[97], edge_weight=[4322])
# Data(num_nodes=98, edge_index=[2, 3900], x=[98, 4], y=[98], edge_weight=[3900])
# outer batch 48
# Data(num_nodes=99, edge_index=[2, 3710], x=[99, 4], y=[99], edge_weight=[3710])
# Data(num_nodes=97, edge_index=[2, 3410], x=[97, 4], y=[97], edge_weight=[3410])
# Data(num_nodes=97, edge_index=[2, 3748], x=[97, 4], y=[97], edge_weight=[3748])
# Data(num_nodes=99, edge_index=[2, 3574], x=[99, 4], y=[99], edge_weight=[3574])
# Data(num_nodes=99, edge_index=[2, 3778], x=[99, 4], y=[99], edge_weight=[3778])
# Data(num_nodes=97, edge_index=[2, 3346], x=[97, 4], y=[97], edge_weight=[3346])
# outer batch 49
# Data(num_nodes=97, edge_index=[2, 3844], x=[97, 4], y=[97], edge_weight=[3844])
# Data(num_nodes=98, edge_index=[2, 3924], x=[98, 4], y=[98], edge_weight=[3924])
# Data(num_nodes=94, edge_index=[2, 4062], x=[94, 4], y=[94], edge_weight=[4062])
# Data(num_nodes=97, edge_index=[2, 3574], x=[97, 4], y=[97], edge_weight=[3574])
# Data(num_nodes=98, edge_index=[2, 3538], x=[98, 4], y=[98], edge_weight=[3538])
# Data(num_nodes=100, edge_index=[2, 3450], x=[100, 4], y=[100], edge_weight=[3450])
# outer batch 50
# Data(num_nodes=95, edge_index=[2, 3668], x=[95, 4], y=[95], edge_weight=[3668])
# Data(num_nodes=92, edge_index=[2, 2796], x=[92, 4], y=[92], edge_weight=[2796])
# Data(num_nodes=98, edge_index=[2, 3752], x=[98, 4], y=[98], edge_weight=[3752])
# Data(num_nodes=95, edge_index=[2, 3344], x=[95, 4], y=[95], edge_weight=[3344])
# Data(num_nodes=100, edge_index=[2, 4030], x=[100, 4], y=[100], edge_weight=[4030])
# Data(num_nodes=98, edge_index=[2, 3600], x=[98, 4], y=[98], edge_weight=[3600])
# outer batch 51
# Data(num_nodes=97, edge_index=[2, 3672], x=[97, 4], y=[97], edge_weight=[3672])
# Data(num_nodes=99, edge_index=[2, 3772], x=[99, 4], y=[99], edge_weight=[3772])
# Data(num_nodes=99, edge_index=[2, 4428], x=[99, 4], y=[99], edge_weight=[4428])
# Data(num_nodes=98, edge_index=[2, 3690], x=[98, 4], y=[98], edge_weight=[3690])
# Data(num_nodes=98, edge_index=[2, 3208], x=[98, 4], y=[98], edge_weight=[3208])
# Data(num_nodes=98, edge_index=[2, 3846], x=[98, 4], y=[98], edge_weight=[3846])
# outer batch 52
# Data(num_nodes=98, edge_index=[2, 3534], x=[98, 4], y=[98], edge_weight=[3534])
# Data(num_nodes=98, edge_index=[2, 3652], x=[98, 4], y=[98], edge_weight=[3652])
# Data(num_nodes=96, edge_index=[2, 4062], x=[96, 4], y=[96], edge_weight=[4062])
# Data(num_nodes=99, edge_index=[2, 4382], x=[99, 4], y=[99], edge_weight=[4382])
# Data(num_nodes=99, edge_index=[2, 3596], x=[99, 4], y=[99], edge_weight=[3596])
# Data(num_nodes=97, edge_index=[2, 3090], x=[97, 4], y=[97], edge_weight=[3090])
# outer batch 53
# Data(num_nodes=96, edge_index=[2, 3366], x=[96, 4], y=[96], edge_weight=[3366])
# Data(num_nodes=95, edge_index=[2, 4078], x=[95, 4], y=[95], edge_weight=[4078])
# Data(num_nodes=97, edge_index=[2, 3548], x=[97, 4], y=[97], edge_weight=[3548])
# Data(num_nodes=96, edge_index=[2, 3128], x=[96, 4], y=[96], edge_weight=[3128])
# Data(num_nodes=98, edge_index=[2, 3872], x=[98, 4], y=[98], edge_weight=[3872])
# Data(num_nodes=96, edge_index=[2, 3702], x=[96, 4], y=[96], edge_weight=[3702])
# outer batch 54
# Data(num_nodes=94, edge_index=[2, 3366], x=[94, 4], y=[94], edge_weight=[3366])
# Data(num_nodes=98, edge_index=[2, 3218], x=[98, 4], y=[98], edge_weight=[3218])
# Data(num_nodes=98, edge_index=[2, 3066], x=[98, 4], y=[98], edge_weight=[3066])
# Data(num_nodes=100, edge_index=[2, 3808], x=[100, 4], y=[100], edge_weight=[3808])
# Data(num_nodes=97, edge_index=[2, 3862], x=[97, 4], y=[97], edge_weight=[3862])
# Data(num_nodes=96, edge_index=[2, 3554], x=[96, 4], y=[96], edge_weight=[3554])
# outer batch 55
# Data(num_nodes=98, edge_index=[2, 4088], x=[98, 4], y=[98], edge_weight=[4088])
# Data(num_nodes=98, edge_index=[2, 3224], x=[98, 4], y=[98], edge_weight=[3224])
# Data(num_nodes=93, edge_index=[2, 3344], x=[93, 4], y=[93], edge_weight=[3344])
# Data(num_nodes=99, edge_index=[2, 3616], x=[99, 4], y=[99], edge_weight=[3616])
# Data(num_nodes=97, edge_index=[2, 3460], x=[97, 4], y=[97], edge_weight=[3460])
# Data(num_nodes=95, edge_index=[2, 3104], x=[95, 4], y=[95], edge_weight=[3104])
# outer batch 56
# Data(num_nodes=96, edge_index=[2, 3276], x=[96, 4], y=[96], edge_weight=[3276])
# Data(num_nodes=97, edge_index=[2, 3748], x=[97, 4], y=[97], edge_weight=[3748])
# Data(num_nodes=99, edge_index=[2, 3706], x=[99, 4], y=[99], edge_weight=[3706])
# Data(num_nodes=96, edge_index=[2, 3372], x=[96, 4], y=[96], edge_weight=[3372])
# Data(num_nodes=100, edge_index=[2, 4156], x=[100, 4], y=[100], edge_weight=[4156])
# Data(num_nodes=100, edge_index=[2, 4228], x=[100, 4], y=[100], edge_weight=[4228])
# outer batch 57
# Data(num_nodes=96, edge_index=[2, 3816], x=[96, 4], y=[96], edge_weight=[3816])
# Data(num_nodes=99, edge_index=[2, 4106], x=[99, 4], y=[99], edge_weight=[4106])
# Data(num_nodes=98, edge_index=[2, 3464], x=[98, 4], y=[98], edge_weight=[3464])
# Data(num_nodes=99, edge_index=[2, 3520], x=[99, 4], y=[99], edge_weight=[3520])
# Data(num_nodes=97, edge_index=[2, 3328], x=[97, 4], y=[97], edge_weight=[3328])
# Data(num_nodes=99, edge_index=[2, 3828], x=[99, 4], y=[99], edge_weight=[3828])
# outer batch 58
# Data(num_nodes=100, edge_index=[2, 3338], x=[100, 4], y=[100], edge_weight=[3338])
# Data(num_nodes=98, edge_index=[2, 3346], x=[98, 4], y=[98], edge_weight=[3346])
# Data(num_nodes=97, edge_index=[2, 3820], x=[97, 4], y=[97], edge_weight=[3820])
# Data(num_nodes=97, edge_index=[2, 3864], x=[97, 4], y=[97], edge_weight=[3864])
# Data(num_nodes=97, edge_index=[2, 3632], x=[97, 4], y=[97], edge_weight=[3632])
# Data(num_nodes=97, edge_index=[2, 3066], x=[97, 4], y=[97], edge_weight=[3066])
# outer batch 59
# Data(num_nodes=95, edge_index=[2, 3768], x=[95, 4], y=[95], edge_weight=[3768])
# Data(num_nodes=98, edge_index=[2, 3738], x=[98, 4], y=[98], edge_weight=[3738])
# Data(num_nodes=97, edge_index=[2, 3838], x=[97, 4], y=[97], edge_weight=[3838])
# Data(num_nodes=100, edge_index=[2, 3982], x=[100, 4], y=[100], edge_weight=[3982])
# Data(num_nodes=99, edge_index=[2, 3690], x=[99, 4], y=[99], edge_weight=[3690])
# Data(num_nodes=98, edge_index=[2, 3398], x=[98, 4], y=[98], edge_weight=[3398])
# outer batch 60
# Data(num_nodes=99, edge_index=[2, 3714], x=[99, 4], y=[99], edge_weight=[3714])
# Data(num_nodes=98, edge_index=[2, 3660], x=[98, 4], y=[98], edge_weight=[3660])
# Data(num_nodes=99, edge_index=[2, 4180], x=[99, 4], y=[99], edge_weight=[4180])
# Data(num_nodes=96, edge_index=[2, 4044], x=[96, 4], y=[96], edge_weight=[4044])
# Data(num_nodes=99, edge_index=[2, 3712], x=[99, 4], y=[99], edge_weight=[3712])
# Data(num_nodes=99, edge_index=[2, 3440], x=[99, 4], y=[99], edge_weight=[3440])
# outer batch 61
# Data(num_nodes=98, edge_index=[2, 3922], x=[98, 4], y=[98], edge_weight=[3922])
# Data(num_nodes=97, edge_index=[2, 3902], x=[97, 4], y=[97], edge_weight=[3902])
# Data(num_nodes=99, edge_index=[2, 3850], x=[99, 4], y=[99], edge_weight=[3850])
# Data(num_nodes=96, edge_index=[2, 3860], x=[96, 4], y=[96], edge_weight=[3860])
# Data(num_nodes=100, edge_index=[2, 3710], x=[100, 4], y=[100], edge_weight=[3710])
# Data(num_nodes=97, edge_index=[2, 3924], x=[97, 4], y=[97], edge_weight=[3924])
# outer batch 62
# Data(num_nodes=96, edge_index=[2, 3334], x=[96, 4], y=[96], edge_weight=[3334])
# Data(num_nodes=100, edge_index=[2, 3418], x=[100, 4], y=[100], edge_weight=[3418])
# Data(num_nodes=98, edge_index=[2, 3536], x=[98, 4], y=[98], edge_weight=[3536])
# Data(num_nodes=98, edge_index=[2, 3578], x=[98, 4], y=[98], edge_weight=[3578])
# Data(num_nodes=100, edge_index=[2, 3566], x=[100, 4], y=[100], edge_weight=[3566])
# Data(num_nodes=94, edge_index=[2, 3032], x=[94, 4], y=[94], edge_weight=[3032])
# outer batch 63
# Data(num_nodes=97, edge_index=[2, 3746], x=[97, 4], y=[97], edge_weight=[3746])
# Data(num_nodes=97, edge_index=[2, 3922], x=[97, 4], y=[97], edge_weight=[3922])
# Data(num_nodes=99, edge_index=[2, 3368], x=[99, 4], y=[99], edge_weight=[3368])
# Data(num_nodes=98, edge_index=[2, 4138], x=[98, 4], y=[98], edge_weight=[4138])
# Data(num_nodes=98, edge_index=[2, 3668], x=[98, 4], y=[98], edge_weight=[3668])
# Data(num_nodes=98, edge_index=[2, 3842], x=[98, 4], y=[98], edge_weight=[3842])
# outer batch 64
# Data(num_nodes=99, edge_index=[2, 3224], x=[99, 4], y=[99], edge_weight=[3224])
# Data(num_nodes=97, edge_index=[2, 3468], x=[97, 4], y=[97], edge_weight=[3468])
# Data(num_nodes=97, edge_index=[2, 3638], x=[97, 4], y=[97], edge_weight=[3638])
# Data(num_nodes=98, edge_index=[2, 3582], x=[98, 4], y=[98], edge_weight=[3582])
# Data(num_nodes=95, edge_index=[2, 3876], x=[95, 4], y=[95], edge_weight=[3876])
# Data(num_nodes=98, edge_index=[2, 3814], x=[98, 4], y=[98], edge_weight=[3814])
# outer batch 65
# Data(num_nodes=97, edge_index=[2, 4034], x=[97, 4], y=[97], edge_weight=[4034])
# Data(num_nodes=97, edge_index=[2, 3852], x=[97, 4], y=[97], edge_weight=[3852])
# Data(num_nodes=99, edge_index=[2, 3790], x=[99, 4], y=[99], edge_weight=[3790])
# Data(num_nodes=98, edge_index=[2, 3398], x=[98, 4], y=[98], edge_weight=[3398])
# Data(num_nodes=99, edge_index=[2, 4342], x=[99, 4], y=[99], edge_weight=[4342])
# Data(num_nodes=98, edge_index=[2, 3480], x=[98, 4], y=[98], edge_weight=[3480])
# outer batch 66
# Data(num_nodes=98, edge_index=[2, 3092], x=[98, 4], y=[98], edge_weight=[3092])
# Data(num_nodes=97, edge_index=[2, 3556], x=[97, 4], y=[97], edge_weight=[3556])
# Data(num_nodes=97, edge_index=[2, 3498], x=[97, 4], y=[97], edge_weight=[3498])
# Data(num_nodes=96, edge_index=[2, 3432], x=[96, 4], y=[96], edge_weight=[3432])
# Data(num_nodes=98, edge_index=[2, 3724], x=[98, 4], y=[98], edge_weight=[3724])
# Data(num_nodes=99, edge_index=[2, 4268], x=[99, 4], y=[99], edge_weight=[4268])
# outer batch 67
# Data(num_nodes=98, edge_index=[2, 3344], x=[98, 4], y=[98], edge_weight=[3344])
# Data(num_nodes=99, edge_index=[2, 3952], x=[99, 4], y=[99], edge_weight=[3952])
# Data(num_nodes=99, edge_index=[2, 3708], x=[99, 4], y=[99], edge_weight=[3708])
# Data(num_nodes=98, edge_index=[2, 3484], x=[98, 4], y=[98], edge_weight=[3484])
# Data(num_nodes=98, edge_index=[2, 3636], x=[98, 4], y=[98], edge_weight=[3636])
# Data(num_nodes=99, edge_index=[2, 3788], x=[99, 4], y=[99], edge_weight=[3788])
# outer batch 68
# Data(num_nodes=98, edge_index=[2, 4286], x=[98, 4], y=[98], edge_weight=[4286])
# Data(num_nodes=97, edge_index=[2, 3742], x=[97, 4], y=[97], edge_weight=[3742])
# Data(num_nodes=99, edge_index=[2, 3896], x=[99, 4], y=[99], edge_weight=[3896])
# Data(num_nodes=97, edge_index=[2, 4396], x=[97, 4], y=[97], edge_weight=[4396])
# Data(num_nodes=97, edge_index=[2, 3008], x=[97, 4], y=[97], edge_weight=[3008])
# Data(num_nodes=97, edge_index=[2, 3650], x=[97, 4], y=[97], edge_weight=[3650])
# outer batch 69
# Data(num_nodes=99, edge_index=[2, 3936], x=[99, 4], y=[99], edge_weight=[3936])
# Data(num_nodes=100, edge_index=[2, 3960], x=[100, 4], y=[100], edge_weight=[3960])
# Data(num_nodes=97, edge_index=[2, 3586], x=[97, 4], y=[97], edge_weight=[3586])
# Data(num_nodes=99, edge_index=[2, 3914], x=[99, 4], y=[99], edge_weight=[3914])
# Data(num_nodes=96, edge_index=[2, 3502], x=[96, 4], y=[96], edge_weight=[3502])
# Data(num_nodes=98, edge_index=[2, 3738], x=[98, 4], y=[98], edge_weight=[3738])
# outer batch 70
# Data(num_nodes=100, edge_index=[2, 4262], x=[100, 4], y=[100], edge_weight=[4262])
# Data(num_nodes=96, edge_index=[2, 3722], x=[96, 4], y=[96], edge_weight=[3722])
# Data(num_nodes=99, edge_index=[2, 4000], x=[99, 4], y=[99], edge_weight=[4000])
# Data(num_nodes=97, edge_index=[2, 4080], x=[97, 4], y=[97], edge_weight=[4080])
# Data(num_nodes=100, edge_index=[2, 3662], x=[100, 4], y=[100], edge_weight=[3662])
# Data(num_nodes=97, edge_index=[2, 3624], x=[97, 4], y=[97], edge_weight=[3624])
# outer batch 71
# Data(num_nodes=94, edge_index=[2, 3370], x=[94, 4], y=[94], edge_weight=[3370])
# Data(num_nodes=97, edge_index=[2, 3310], x=[97, 4], y=[97], edge_weight=[3310])
# Data(num_nodes=97, edge_index=[2, 3774], x=[97, 4], y=[97], edge_weight=[3774])
# Data(num_nodes=96, edge_index=[2, 3568], x=[96, 4], y=[96], edge_weight=[3568])
# Data(num_nodes=97, edge_index=[2, 3702], x=[97, 4], y=[97], edge_weight=[3702])
# Data(num_nodes=99, edge_index=[2, 4230], x=[99, 4], y=[99], edge_weight=[4230])
# outer batch 72
# Data(num_nodes=98, edge_index=[2, 3860], x=[98, 4], y=[98], edge_weight=[3860])
# Data(num_nodes=98, edge_index=[2, 4022], x=[98, 4], y=[98], edge_weight=[4022])
# Data(num_nodes=95, edge_index=[2, 3552], x=[95, 4], y=[95], edge_weight=[3552])
# Data(num_nodes=99, edge_index=[2, 3728], x=[99, 4], y=[99], edge_weight=[3728])
# Data(num_nodes=99, edge_index=[2, 3530], x=[99, 4], y=[99], edge_weight=[3530])
# Data(num_nodes=95, edge_index=[2, 3468], x=[95, 4], y=[95], edge_weight=[3468])
# outer batch 73
# Data(num_nodes=97, edge_index=[2, 3450], x=[97, 4], y=[97], edge_weight=[3450])
# Data(num_nodes=99, edge_index=[2, 3856], x=[99, 4], y=[99], edge_weight=[3856])
# Data(num_nodes=98, edge_index=[2, 3974], x=[98, 4], y=[98], edge_weight=[3974])
# Data(num_nodes=98, edge_index=[2, 3454], x=[98, 4], y=[98], edge_weight=[3454])
# Data(num_nodes=95, edge_index=[2, 3278], x=[95, 4], y=[95], edge_weight=[3278])
# Data(num_nodes=98, edge_index=[2, 3516], x=[98, 4], y=[98], edge_weight=[3516])
# outer batch 74
# Data(num_nodes=98, edge_index=[2, 4164], x=[98, 4], y=[98], edge_weight=[4164])
# Data(num_nodes=96, edge_index=[2, 3530], x=[96, 4], y=[96], edge_weight=[3530])
# Data(num_nodes=98, edge_index=[2, 3520], x=[98, 4], y=[98], edge_weight=[3520])
# Data(num_nodes=98, edge_index=[2, 4512], x=[98, 4], y=[98], edge_weight=[4512])
# Data(num_nodes=100, edge_index=[2, 3760], x=[100, 4], y=[100], edge_weight=[3760])
# Data(num_nodes=99, edge_index=[2, 4030], x=[99, 4], y=[99], edge_weight=[4030])
# outer batch 75
# Data(num_nodes=99, edge_index=[2, 3736], x=[99, 4], y=[99], edge_weight=[3736])
# Data(num_nodes=98, edge_index=[2, 3690], x=[98, 4], y=[98], edge_weight=[3690])
# Data(num_nodes=95, edge_index=[2, 3336], x=[95, 4], y=[95], edge_weight=[3336])
# Data(num_nodes=98, edge_index=[2, 3826], x=[98, 4], y=[98], edge_weight=[3826])
# Data(num_nodes=100, edge_index=[2, 4008], x=[100, 4], y=[100], edge_weight=[4008])
# Data(num_nodes=98, edge_index=[2, 3598], x=[98, 4], y=[98], edge_weight=[3598])
# outer batch 76
# Data(num_nodes=97, edge_index=[2, 3112], x=[97, 4], y=[97], edge_weight=[3112])
# Data(num_nodes=96, edge_index=[2, 3894], x=[96, 4], y=[96], edge_weight=[3894])
# Data(num_nodes=99, edge_index=[2, 4006], x=[99, 4], y=[99], edge_weight=[4006])
# Data(num_nodes=98, edge_index=[2, 4014], x=[98, 4], y=[98], edge_weight=[4014])
# Data(num_nodes=99, edge_index=[2, 4284], x=[99, 4], y=[99], edge_weight=[4284])
# Data(num_nodes=99, edge_index=[2, 3708], x=[99, 4], y=[99], edge_weight=[3708])
# outer batch 77
# Data(num_nodes=97, edge_index=[2, 3782], x=[97, 4], y=[97], edge_weight=[3782])
# Data(num_nodes=98, edge_index=[2, 4232], x=[98, 4], y=[98], edge_weight=[4232])
# Data(num_nodes=99, edge_index=[2, 3668], x=[99, 4], y=[99], edge_weight=[3668])
# Data(num_nodes=100, edge_index=[2, 3982], x=[100, 4], y=[100], edge_weight=[3982])
# Data(num_nodes=100, edge_index=[2, 4086], x=[100, 4], y=[100], edge_weight=[4086])
# Data(num_nodes=95, edge_index=[2, 3786], x=[95, 4], y=[95], edge_weight=[3786])
# outer batch 78
# Data(num_nodes=95, edge_index=[2, 3626], x=[95, 4], y=[95], edge_weight=[3626])
# Data(num_nodes=99, edge_index=[2, 4292], x=[99, 4], y=[99], edge_weight=[4292])
# Data(num_nodes=99, edge_index=[2, 3320], x=[99, 4], y=[99], edge_weight=[3320])
# Data(num_nodes=100, edge_index=[2, 4420], x=[100, 4], y=[100], edge_weight=[4420])
# Data(num_nodes=98, edge_index=[2, 4230], x=[98, 4], y=[98], edge_weight=[4230])
# Data(num_nodes=94, edge_index=[2, 3702], x=[94, 4], y=[94], edge_weight=[3702])
# outer batch 79
# Data(num_nodes=98, edge_index=[2, 3064], x=[98, 4], y=[98], edge_weight=[3064])
# Data(num_nodes=99, edge_index=[2, 4136], x=[99, 4], y=[99], edge_weight=[4136])
# Data(num_nodes=97, edge_index=[2, 4196], x=[97, 4], y=[97], edge_weight=[4196])
# Data(num_nodes=99, edge_index=[2, 4226], x=[99, 4], y=[99], edge_weight=[4226])
# Data(num_nodes=99, edge_index=[2, 3796], x=[99, 4], y=[99], edge_weight=[3796])
# Data(num_nodes=100, edge_index=[2, 4442], x=[100, 4], y=[100], edge_weight=[4442])
# outer batch 80
# Data(num_nodes=98, edge_index=[2, 3674], x=[98, 4], y=[98], edge_weight=[3674])
# Data(num_nodes=100, edge_index=[2, 3750], x=[100, 4], y=[100], edge_weight=[3750])
# Data(num_nodes=98, edge_index=[2, 3840], x=[98, 4], y=[98], edge_weight=[3840])
# Data(num_nodes=96, edge_index=[2, 4104], x=[96, 4], y=[96], edge_weight=[4104])
# Data(num_nodes=96, edge_index=[2, 3124], x=[96, 4], y=[96], edge_weight=[3124])
# Data(num_nodes=98, edge_index=[2, 3676], x=[98, 4], y=[98], edge_weight=[3676])
# outer batch 81
# Data(num_nodes=99, edge_index=[2, 4438], x=[99, 4], y=[99], edge_weight=[4438])
# Data(num_nodes=96, edge_index=[2, 3204], x=[96, 4], y=[96], edge_weight=[3204])
# Data(num_nodes=98, edge_index=[2, 3992], x=[98, 4], y=[98], edge_weight=[3992])
# Data(num_nodes=97, edge_index=[2, 4122], x=[97, 4], y=[97], edge_weight=[4122])
# Data(num_nodes=99, edge_index=[2, 3460], x=[99, 4], y=[99], edge_weight=[3460])
# Data(num_nodes=99, edge_index=[2, 3794], x=[99, 4], y=[99], edge_weight=[3794])
# outer batch 82
# Data(num_nodes=99, edge_index=[2, 4090], x=[99, 4], y=[99], edge_weight=[4090])
# Data(num_nodes=97, edge_index=[2, 3894], x=[97, 4], y=[97], edge_weight=[3894])
# Data(num_nodes=94, edge_index=[2, 3644], x=[94, 4], y=[94], edge_weight=[3644])
# Data(num_nodes=94, edge_index=[2, 3018], x=[94, 4], y=[94], edge_weight=[3018])
# Data(num_nodes=99, edge_index=[2, 3346], x=[99, 4], y=[99], edge_weight=[3346])
# Data(num_nodes=99, edge_index=[2, 4402], x=[99, 4], y=[99], edge_weight=[4402])
# outer batch 83
# Data(num_nodes=100, edge_index=[2, 5326], x=[100, 4], y=[100], edge_weight=[5326])
# Data(num_nodes=98, edge_index=[2, 3754], x=[98, 4], y=[98], edge_weight=[3754])
# Data(num_nodes=97, edge_index=[2, 3260], x=[97, 4], y=[97], edge_weight=[3260])
# Data(num_nodes=98, edge_index=[2, 3490], x=[98, 4], y=[98], edge_weight=[3490])
# Data(num_nodes=97, edge_index=[2, 3930], x=[97, 4], y=[97], edge_weight=[3930])
# Data(num_nodes=98, edge_index=[2, 3848], x=[98, 4], y=[98], edge_weight=[3848])
# outer batch 84
# Data(num_nodes=99, edge_index=[2, 3688], x=[99, 4], y=[99], edge_weight=[3688])
# Data(num_nodes=99, edge_index=[2, 3770], x=[99, 4], y=[99], edge_weight=[3770])
# Data(num_nodes=99, edge_index=[2, 3808], x=[99, 4], y=[99], edge_weight=[3808])
# Data(num_nodes=96, edge_index=[2, 3868], x=[96, 4], y=[96], edge_weight=[3868])
# Data(num_nodes=97, edge_index=[2, 3874], x=[97, 4], y=[97], edge_weight=[3874])
# Data(num_nodes=96, edge_index=[2, 3166], x=[96, 4], y=[96], edge_weight=[3166])
# outer batch 85
# Data(num_nodes=99, edge_index=[2, 3416], x=[99, 4], y=[99], edge_weight=[3416])
# Data(num_nodes=97, edge_index=[2, 3982], x=[97, 4], y=[97], edge_weight=[3982])
# Data(num_nodes=97, edge_index=[2, 3452], x=[97, 4], y=[97], edge_weight=[3452])
# Data(num_nodes=99, edge_index=[2, 3850], x=[99, 4], y=[99], edge_weight=[3850])
# Data(num_nodes=100, edge_index=[2, 3522], x=[100, 4], y=[100], edge_weight=[3522])
# Data(num_nodes=96, edge_index=[2, 3570], x=[96, 4], y=[96], edge_weight=[3570])
# outer batch 86
# Data(num_nodes=98, edge_index=[2, 3774], x=[98, 4], y=[98], edge_weight=[3774])
# Data(num_nodes=97, edge_index=[2, 3502], x=[97, 4], y=[97], edge_weight=[3502])
# Data(num_nodes=99, edge_index=[2, 3610], x=[99, 4], y=[99], edge_weight=[3610])
# Data(num_nodes=99, edge_index=[2, 3622], x=[99, 4], y=[99], edge_weight=[3622])
# Data(num_nodes=99, edge_index=[2, 3026], x=[99, 4], y=[99], edge_weight=[3026])
# Data(num_nodes=96, edge_index=[2, 3522], x=[96, 4], y=[96], edge_weight=[3522])
# outer batch 87
# Data(num_nodes=99, edge_index=[2, 4404], x=[99, 4], y=[99], edge_weight=[4404])
# Data(num_nodes=96, edge_index=[2, 3696], x=[96, 4], y=[96], edge_weight=[3696])
# Data(num_nodes=95, edge_index=[2, 4268], x=[95, 4], y=[95], edge_weight=[4268])
# Data(num_nodes=99, edge_index=[2, 3802], x=[99, 4], y=[99], edge_weight=[3802])
# Data(num_nodes=96, edge_index=[2, 3612], x=[96, 4], y=[96], edge_weight=[3612])
# Data(num_nodes=98, edge_index=[2, 3356], x=[98, 4], y=[98], edge_weight=[3356])
# outer batch 88
# Data(num_nodes=95, edge_index=[2, 2970], x=[95, 4], y=[95], edge_weight=[2970])
# Data(num_nodes=96, edge_index=[2, 3388], x=[96, 4], y=[96], edge_weight=[3388])
# Data(num_nodes=99, edge_index=[2, 3980], x=[99, 4], y=[99], edge_weight=[3980])
# Data(num_nodes=99, edge_index=[2, 3598], x=[99, 4], y=[99], edge_weight=[3598])
# Data(num_nodes=98, edge_index=[2, 3700], x=[98, 4], y=[98], edge_weight=[3700])
# Data(num_nodes=99, edge_index=[2, 3744], x=[99, 4], y=[99], edge_weight=[3744])
# outer batch 89
# Data(num_nodes=100, edge_index=[2, 4262], x=[100, 4], y=[100], edge_weight=[4262])
# Data(num_nodes=98, edge_index=[2, 3840], x=[98, 4], y=[98], edge_weight=[3840])
# Data(num_nodes=100, edge_index=[2, 3908], x=[100, 4], y=[100], edge_weight=[3908])
# Data(num_nodes=97, edge_index=[2, 3784], x=[97, 4], y=[97], edge_weight=[3784])
# Data(num_nodes=97, edge_index=[2, 3378], x=[97, 4], y=[97], edge_weight=[3378])
# Data(num_nodes=100, edge_index=[2, 3766], x=[100, 4], y=[100], edge_weight=[3766])
# outer batch 90
# Data(num_nodes=99, edge_index=[2, 3266], x=[99, 4], y=[99], edge_weight=[3266])
# Data(num_nodes=99, edge_index=[2, 3628], x=[99, 4], y=[99], edge_weight=[3628])
# Data(num_nodes=96, edge_index=[2, 3810], x=[96, 4], y=[96], edge_weight=[3810])
# Data(num_nodes=99, edge_index=[2, 4046], x=[99, 4], y=[99], edge_weight=[4046])
# Data(num_nodes=94, edge_index=[2, 3952], x=[94, 4], y=[94], edge_weight=[3952])
# Data(num_nodes=96, edge_index=[2, 3560], x=[96, 4], y=[96], edge_weight=[3560])
# outer batch 91
# Data(num_nodes=99, edge_index=[2, 3982], x=[99, 4], y=[99], edge_weight=[3982])
# Data(num_nodes=98, edge_index=[2, 3910], x=[98, 4], y=[98], edge_weight=[3910])
# Data(num_nodes=99, edge_index=[2, 3652], x=[99, 4], y=[99], edge_weight=[3652])
# Data(num_nodes=98, edge_index=[2, 3674], x=[98, 4], y=[98], edge_weight=[3674])
# Data(num_nodes=99, edge_index=[2, 3518], x=[99, 4], y=[99], edge_weight=[3518])
# Data(num_nodes=99, edge_index=[2, 3942], x=[99, 4], y=[99], edge_weight=[3942])
# outer batch 92
# Data(num_nodes=96, edge_index=[2, 3886], x=[96, 4], y=[96], edge_weight=[3886])
# Data(num_nodes=94, edge_index=[2, 3384], x=[94, 4], y=[94], edge_weight=[3384])
# Data(num_nodes=97, edge_index=[2, 3880], x=[97, 4], y=[97], edge_weight=[3880])
# Data(num_nodes=96, edge_index=[2, 3170], x=[96, 4], y=[96], edge_weight=[3170])
# Data(num_nodes=96, edge_index=[2, 3762], x=[96, 4], y=[96], edge_weight=[3762])
# Data(num_nodes=99, edge_index=[2, 3768], x=[99, 4], y=[99], edge_weight=[3768])
# outer batch 93
# Data(num_nodes=100, edge_index=[2, 3982], x=[100, 4], y=[100], edge_weight=[3982])
# Data(num_nodes=98, edge_index=[2, 3974], x=[98, 4], y=[98], edge_weight=[3974])
# Data(num_nodes=98, edge_index=[2, 3284], x=[98, 4], y=[98], edge_weight=[3284])
# Data(num_nodes=97, edge_index=[2, 4054], x=[97, 4], y=[97], edge_weight=[4054])
# Data(num_nodes=97, edge_index=[2, 3450], x=[97, 4], y=[97], edge_weight=[3450])
# Data(num_nodes=98, edge_index=[2, 3884], x=[98, 4], y=[98], edge_weight=[3884])
# outer batch 94
# Data(num_nodes=98, edge_index=[2, 3744], x=[98, 4], y=[98], edge_weight=[3744])
# Data(num_nodes=97, edge_index=[2, 3500], x=[97, 4], y=[97], edge_weight=[3500])
# Data(num_nodes=97, edge_index=[2, 4240], x=[97, 4], y=[97], edge_weight=[4240])
# Data(num_nodes=99, edge_index=[2, 3320], x=[99, 4], y=[99], edge_weight=[3320])
# Data(num_nodes=99, edge_index=[2, 4208], x=[99, 4], y=[99], edge_weight=[4208])
# Data(num_nodes=98, edge_index=[2, 3262], x=[98, 4], y=[98], edge_weight=[3262])
# outer batch 95
# Data(num_nodes=98, edge_index=[2, 3434], x=[98, 4], y=[98], edge_weight=[3434])
# Data(num_nodes=97, edge_index=[2, 3546], x=[97, 4], y=[97], edge_weight=[3546])
# Data(num_nodes=97, edge_index=[2, 4146], x=[97, 4], y=[97], edge_weight=[4146])
# Data(num_nodes=99, edge_index=[2, 4018], x=[99, 4], y=[99], edge_weight=[4018])
# Data(num_nodes=96, edge_index=[2, 3226], x=[96, 4], y=[96], edge_weight=[3226])
# Data(num_nodes=98, edge_index=[2, 3818], x=[98, 4], y=[98], edge_weight=[3818])
# outer batch 96
# Data(num_nodes=97, edge_index=[2, 3314], x=[97, 4], y=[97], edge_weight=[3314])
# Data(num_nodes=99, edge_index=[2, 3886], x=[99, 4], y=[99], edge_weight=[3886])
# Data(num_nodes=99, edge_index=[2, 3692], x=[99, 4], y=[99], edge_weight=[3692])
# Data(num_nodes=98, edge_index=[2, 3522], x=[98, 4], y=[98], edge_weight=[3522])
# ...
# outer batch 187
# Data(num_nodes=100, edge_index=[2, 4336], x=[100, 4], y=[100], edge_weight=[4336])
# Data(num_nodes=100, edge_index=[2, 3236], x=[100, 4], y=[100], edge_weight=[3236])
# Data(num_nodes=97, edge_index=[2, 3530], x=[97, 4], y=[97], edge_weight=[3530])
# Data(num_nodes=99, edge_index=[2, 3568], x=[99, 4], y=[99], edge_weight=[3568])
# Data(num_nodes=99, edge_index=[2, 4144], x=[99, 4], y=[99], edge_weight=[4144])
# Data(num_nodes=97, edge_index=[2, 4016], x=[97, 4], y=[97], edge_weight=[4016])
# outer batch 188
# Data(num_nodes=100, edge_index=[2, 4010], x=[100, 4], y=[100], edge_weight=[4010])
# Data(num_nodes=97, edge_index=[2, 3908], x=[97, 4], y=[97], edge_weight=[3908])
# Data(num_nodes=99, edge_index=[2, 3778], x=[99, 4], y=[99], edge_weight=[3778])
# Data(num_nodes=99, edge_index=[2, 4034], x=[99, 4], y=[99], edge_weight=[4034])
# Data(num_nodes=96, edge_index=[2, 4202], x=[96, 4], y=[96], edge_weight=[4202])
# Data(num_nodes=100, edge_index=[2, 3812], x=[100, 4], y=[100], edge_weight=[3812])
# outer batch 189
# Data(num_nodes=98, edge_index=[2, 3580], x=[98, 4], y=[98], edge_weight=[3580])
# Data(num_nodes=96, edge_index=[2, 3792], x=[96, 4], y=[96], edge_weight=[3792])
# Data(num_nodes=96, edge_index=[2, 3178], x=[96, 4], y=[96], edge_weight=[3178])
# Data(num_nodes=97, edge_index=[2, 3746], x=[97, 4], y=[97], edge_weight=[3746])
# Data(num_nodes=100, edge_index=[2, 4094], x=[100, 4], y=[100], edge_weight=[4094])
# Data(num_nodes=96, edge_index=[2, 3496], x=[96, 4], y=[96], edge_weight=[3496])
# outer batch 190
# Data(num_nodes=95, edge_index=[2, 3298], x=[95, 4], y=[95], edge_weight=[3298])
# Data(num_nodes=96, edge_index=[2, 3494], x=[96, 4], y=[96], edge_weight=[3494])
# Data(num_nodes=98, edge_index=[2, 3540], x=[98, 4], y=[98], edge_weight=[3540])
# Data(num_nodes=96, edge_index=[2, 3964], x=[96, 4], y=[96], edge_weight=[3964])
# Data(num_nodes=94, edge_index=[2, 4180], x=[94, 4], y=[94], edge_weight=[4180])
# Data(num_nodes=94, edge_index=[2, 3930], x=[94, 4], y=[94], edge_weight=[3930])
# outer batch 191
# Data(num_nodes=95, edge_index=[2, 3544], x=[95, 4], y=[95], edge_weight=[3544])
# Data(num_nodes=98, edge_index=[2, 3916], x=[98, 4], y=[98], edge_weight=[3916])
# Data(num_nodes=96, edge_index=[2, 3394], x=[96, 4], y=[96], edge_weight=[3394])
# Data(num_nodes=97, edge_index=[2, 4046], x=[97, 4], y=[97], edge_weight=[4046])
# Data(num_nodes=97, edge_index=[2, 4018], x=[97, 4], y=[97], edge_weight=[4018])
# Data(num_nodes=99, edge_index=[2, 3442], x=[99, 4], y=[99], edge_weight=[3442])
# outer batch 192
# Data(num_nodes=100, edge_index=[2, 3270], x=[100, 4], y=[100], edge_weight=[3270])
# Data(num_nodes=96, edge_index=[2, 3392], x=[96, 4], y=[96], edge_weight=[3392])
# Data(num_nodes=100, edge_index=[2, 4388], x=[100, 4], y=[100], edge_weight=[4388])
# Data(num_nodes=95, edge_index=[2, 4216], x=[95, 4], y=[95], edge_weight=[4216])
# Data(num_nodes=97, edge_index=[2, 4020], x=[97, 4], y=[97], edge_weight=[4020])
# Data(num_nodes=93, edge_index=[2, 3056], x=[93, 4], y=[93], edge_weight=[3056])
# outer batch 193
# Data(num_nodes=98, edge_index=[2, 4016], x=[98, 4], y=[98], edge_weight=[4016])
# Data(num_nodes=98, edge_index=[2, 3808], x=[98, 4], y=[98], edge_weight=[3808])
# Data(num_nodes=98, edge_index=[2, 3468], x=[98, 4], y=[98], edge_weight=[3468])
# Data(num_nodes=97, edge_index=[2, 3572], x=[97, 4], y=[97], edge_weight=[3572])
# Data(num_nodes=99, edge_index=[2, 4730], x=[99, 4], y=[99], edge_weight=[4730])
# Data(num_nodes=99, edge_index=[2, 3948], x=[99, 4], y=[99], edge_weight=[3948])
# outer batch 194
# Data(num_nodes=100, edge_index=[2, 3932], x=[100, 4], y=[100], edge_weight=[3932])
# Data(num_nodes=98, edge_index=[2, 4382], x=[98, 4], y=[98], edge_weight=[4382])
# Data(num_nodes=98, edge_index=[2, 3688], x=[98, 4], y=[98], edge_weight=[3688])
# Data(num_nodes=100, edge_index=[2, 3506], x=[100, 4], y=[100], edge_weight=[3506])
# Data(num_nodes=100, edge_index=[2, 4492], x=[100, 4], y=[100], edge_weight=[4492])
# Data(num_nodes=99, edge_index=[2, 3468], x=[99, 4], y=[99], edge_weight=[3468])
# outer batch 195
# Data(num_nodes=96, edge_index=[2, 3900], x=[96, 4], y=[96], edge_weight=[3900])
# Data(num_nodes=98, edge_index=[2, 3874], x=[98, 4], y=[98], edge_weight=[3874])
# Data(num_nodes=98, edge_index=[2, 3386], x=[98, 4], y=[98], edge_weight=[3386])
# Data(num_nodes=97, edge_index=[2, 3790], x=[97, 4], y=[97], edge_weight=[3790])
# Data(num_nodes=95, edge_index=[2, 4514], x=[95, 4], y=[95], edge_weight=[4514])
# Data(num_nodes=96, edge_index=[2, 3560], x=[96, 4], y=[96], edge_weight=[3560])
# outer batch 196
# Data(num_nodes=98, edge_index=[2, 3716], x=[98, 4], y=[98], edge_weight=[3716])
# Data(num_nodes=96, edge_index=[2, 3832], x=[96, 4], y=[96], edge_weight=[3832])
# Data(num_nodes=97, edge_index=[2, 3842], x=[97, 4], y=[97], edge_weight=[3842])
# Data(num_nodes=97, edge_index=[2, 3290], x=[97, 4], y=[97], edge_weight=[3290])
# Data(num_nodes=99, edge_index=[2, 3442], x=[99, 4], y=[99], edge_weight=[3442])
# Data(num_nodes=100, edge_index=[2, 3644], x=[100, 4], y=[100], edge_weight=[3644])
# outer batch 197
# Data(num_nodes=98, edge_index=[2, 4040], x=[98, 4], y=[98], edge_weight=[4040])
# Data(num_nodes=97, edge_index=[2, 3232], x=[97, 4], y=[97], edge_weight=[3232])
# Data(num_nodes=97, edge_index=[2, 3510], x=[97, 4], y=[97], edge_weight=[3510])
# Data(num_nodes=100, edge_index=[2, 4470], x=[100, 4], y=[100], edge_weight=[4470])
# Data(num_nodes=100, edge_index=[2, 4296], x=[100, 4], y=[100], edge_weight=[4296])
# Data(num_nodes=95, edge_index=[2, 3384], x=[95, 4], y=[95], edge_weight=[3384])
# outer batch 198
# Data(num_nodes=97, edge_index=[2, 3906], x=[97, 4], y=[97], edge_weight=[3906])
# Data(num_nodes=98, edge_index=[2, 3336], x=[98, 4], y=[98], edge_weight=[3336])
# Data(num_nodes=97, edge_index=[2, 4094], x=[97, 4], y=[97], edge_weight=[4094])
# Data(num_nodes=99, edge_index=[2, 3310], x=[99, 4], y=[99], edge_weight=[3310])
# Data(num_nodes=99, edge_index=[2, 4294], x=[99, 4], y=[99], edge_weight=[4294])
# Data(num_nodes=99, edge_index=[2, 3500], x=[99, 4], y=[99], edge_weight=[3500])
# outer batch 199
# Data(num_nodes=98, edge_index=[2, 4396], x=[98, 4], y=[98], edge_weight=[4396])
# Data(num_nodes=96, edge_index=[2, 3678], x=[96, 4], y=[96], edge_weight=[3678])
# Data(num_nodes=98, edge_index=[2, 3482], x=[98, 4], y=[98], edge_weight=[3482])
# Data(num_nodes=96, edge_index=[2, 3820], x=[96, 4], y=[96], edge_weight=[3820])
# Data(num_nodes=95, edge_index=[2, 3782], x=[95, 4], y=[95], edge_weight=[3782])
# Data(num_nodes=97, edge_index=[2, 3642], x=[97, 4], y=[97], edge_weight=[3642])
# outer batch 200
# Data(num_nodes=97, edge_index=[2, 3702], x=[97, 4], y=[97], edge_weight=[3702])
# Data(num_nodes=98, edge_index=[2, 3726], x=[98, 4], y=[98], edge_weight=[3726])
# Data(num_nodes=100, edge_index=[2, 3514], x=[100, 4], y=[100], edge_weight=[3514])
# Data(num_nodes=98, edge_index=[2, 3606], x=[98, 4], y=[98], edge_weight=[3606])
# Data(num_nodes=98, edge_index=[2, 4272], x=[98, 4], y=[98], edge_weight=[4272])
# Data(num_nodes=99, edge_index=[2, 4214], x=[99, 4], y=[99], edge_weight=[4214])
# outer batch 201
# Data(num_nodes=100, edge_index=[2, 4032], x=[100, 4], y=[100], edge_weight=[4032])
# Data(num_nodes=99, edge_index=[2, 3856], x=[99, 4], y=[99], edge_weight=[3856])
# Data(num_nodes=98, edge_index=[2, 3974], x=[98, 4], y=[98], edge_weight=[3974])
# Data(num_nodes=100, edge_index=[2, 3460], x=[100, 4], y=[100], edge_weight=[3460])
# Data(num_nodes=97, edge_index=[2, 3150], x=[97, 4], y=[97], edge_weight=[3150])
# Data(num_nodes=99, edge_index=[2, 4362], x=[99, 4], y=[99], edge_weight=[4362])
# outer batch 202
# Data(num_nodes=98, edge_index=[2, 3938], x=[98, 4], y=[98], edge_weight=[3938])
# Data(num_nodes=97, edge_index=[2, 3632], x=[97, 4], y=[97], edge_weight=[3632])
# Data(num_nodes=95, edge_index=[2, 3842], x=[95, 4], y=[95], edge_weight=[3842])
# Data(num_nodes=99, edge_index=[2, 3966], x=[99, 4], y=[99], edge_weight=[3966])
# Data(num_nodes=98, edge_index=[2, 3134], x=[98, 4], y=[98], edge_weight=[3134])
# Data(num_nodes=100, edge_index=[2, 3822], x=[100, 4], y=[100], edge_weight=[3822])
# outer batch 203
# Data(num_nodes=95, edge_index=[2, 3186], x=[95, 4], y=[95], edge_weight=[3186])
# Data(num_nodes=97, edge_index=[2, 3914], x=[97, 4], y=[97], edge_weight=[3914])
# Data(num_nodes=100, edge_index=[2, 3548], x=[100, 4], y=[100], edge_weight=[3548])
# Data(num_nodes=97, edge_index=[2, 2878], x=[97, 4], y=[97], edge_weight=[2878])
# Data(num_nodes=95, edge_index=[2, 3880], x=[95, 4], y=[95], edge_weight=[3880])
# Data(num_nodes=98, edge_index=[2, 3354], x=[98, 4], y=[98], edge_weight=[3354])
# outer batch 204
# Data(num_nodes=98, edge_index=[2, 3948], x=[98, 4], y=[98], edge_weight=[3948])
# Data(num_nodes=97, edge_index=[2, 3844], x=[97, 4], y=[97], edge_weight=[3844])
# Data(num_nodes=99, edge_index=[2, 4338], x=[99, 4], y=[99], edge_weight=[4338])
# Data(num_nodes=98, edge_index=[2, 4074], x=[98, 4], y=[98], edge_weight=[4074])
# Data(num_nodes=98, edge_index=[2, 4398], x=[98, 4], y=[98], edge_weight=[4398])
# Data(num_nodes=99, edge_index=[2, 3482], x=[99, 4], y=[99], edge_weight=[3482])
# outer batch 205
# Data(num_nodes=98, edge_index=[2, 3818], x=[98, 4], y=[98], edge_weight=[3818])
# Data(num_nodes=98, edge_index=[2, 4004], x=[98, 4], y=[98], edge_weight=[4004])
# Data(num_nodes=99, edge_index=[2, 3978], x=[99, 4], y=[99], edge_weight=[3978])
# Data(num_nodes=98, edge_index=[2, 4080], x=[98, 4], y=[98], edge_weight=[4080])
# Data(num_nodes=98, edge_index=[2, 3436], x=[98, 4], y=[98], edge_weight=[3436])
# Data(num_nodes=99, edge_index=[2, 3604], x=[99, 4], y=[99], edge_weight=[3604])
# outer batch 206
# Data(num_nodes=98, edge_index=[2, 3600], x=[98, 4], y=[98], edge_weight=[3600])
# Data(num_nodes=100, edge_index=[2, 3922], x=[100, 4], y=[100], edge_weight=[3922])
# Data(num_nodes=98, edge_index=[2, 3636], x=[98, 4], y=[98], edge_weight=[3636])
# Data(num_nodes=98, edge_index=[2, 3356], x=[98, 4], y=[98], edge_weight=[3356])
# Data(num_nodes=97, edge_index=[2, 3584], x=[97, 4], y=[97], edge_weight=[3584])
# Data(num_nodes=97, edge_index=[2, 3784], x=[97, 4], y=[97], edge_weight=[3784])
# outer batch 207
# Data(num_nodes=97, edge_index=[2, 4280], x=[97, 4], y=[97], edge_weight=[4280])
# Data(num_nodes=98, edge_index=[2, 3774], x=[98, 4], y=[98], edge_weight=[3774])
# Data(num_nodes=98, edge_index=[2, 4100], x=[98, 4], y=[98], edge_weight=[4100])
# Data(num_nodes=96, edge_index=[2, 3156], x=[96, 4], y=[96], edge_weight=[3156])
# Data(num_nodes=99, edge_index=[2, 3814], x=[99, 4], y=[99], edge_weight=[3814])
# Data(num_nodes=98, edge_index=[2, 3778], x=[98, 4], y=[98], edge_weight=[3778])
# outer batch 208
# Data(num_nodes=98, edge_index=[2, 3136], x=[98, 4], y=[98], edge_weight=[3136])
# Data(num_nodes=98, edge_index=[2, 3780], x=[98, 4], y=[98], edge_weight=[3780])
# Data(num_nodes=95, edge_index=[2, 3108], x=[95, 4], y=[95], edge_weight=[3108])
# Data(num_nodes=99, edge_index=[2, 3798], x=[99, 4], y=[99], edge_weight=[3798])
# Data(num_nodes=100, edge_index=[2, 4130], x=[100, 4], y=[100], edge_weight=[4130])
# Data(num_nodes=100, edge_index=[2, 3408], x=[100, 4], y=[100], edge_weight=[3408])
# outer batch 209
# Data(num_nodes=99, edge_index=[2, 3370], x=[99, 4], y=[99], edge_weight=[3370])
# Data(num_nodes=98, edge_index=[2, 4014], x=[98, 4], y=[98], edge_weight=[4014])
# Data(num_nodes=95, edge_index=[2, 3554], x=[95, 4], y=[95], edge_weight=[3554])
# Data(num_nodes=97, edge_index=[2, 3168], x=[97, 4], y=[97], edge_weight=[3168])
# Data(num_nodes=99, edge_index=[2, 3698], x=[99, 4], y=[99], edge_weight=[3698])
# Data(num_nodes=97, edge_index=[2, 3296], x=[97, 4], y=[97], edge_weight=[3296])
# outer batch 210
# Data(num_nodes=99, edge_index=[2, 4392], x=[99, 4], y=[99], edge_weight=[4392])
# Data(num_nodes=98, edge_index=[2, 3776], x=[98, 4], y=[98], edge_weight=[3776])
# Data(num_nodes=98, edge_index=[2, 3912], x=[98, 4], y=[98], edge_weight=[3912])
# Data(num_nodes=98, edge_index=[2, 3732], x=[98, 4], y=[98], edge_weight=[3732])
# Data(num_nodes=97, edge_index=[2, 3470], x=[97, 4], y=[97], edge_weight=[3470])
# Data(num_nodes=99, edge_index=[2, 3686], x=[99, 4], y=[99], edge_weight=[3686])
# outer batch 211
# Data(num_nodes=98, edge_index=[2, 3522], x=[98, 4], y=[98], edge_weight=[3522])
# Data(num_nodes=99, edge_index=[2, 3536], x=[99, 4], y=[99], edge_weight=[3536])
# Data(num_nodes=98, edge_index=[2, 4696], x=[98, 4], y=[98], edge_weight=[4696])
# Data(num_nodes=97, edge_index=[2, 3550], x=[97, 4], y=[97], edge_weight=[3550])
# Data(num_nodes=99, edge_index=[2, 3998], x=[99, 4], y=[99], edge_weight=[3998])
# Data(num_nodes=98, edge_index=[2, 4070], x=[98, 4], y=[98], edge_weight=[4070])
# outer batch 212
# Data(num_nodes=97, edge_index=[2, 3680], x=[97, 4], y=[97], edge_weight=[3680])
# Data(num_nodes=96, edge_index=[2, 3438], x=[96, 4], y=[96], edge_weight=[3438])
# Data(num_nodes=96, edge_index=[2, 3406], x=[96, 4], y=[96], edge_weight=[3406])
# Data(num_nodes=99, edge_index=[2, 4074], x=[99, 4], y=[99], edge_weight=[4074])
# Data(num_nodes=97, edge_index=[2, 3628], x=[97, 4], y=[97], edge_weight=[3628])
# Data(num_nodes=99, edge_index=[2, 3688], x=[99, 4], y=[99], edge_weight=[3688])
# outer batch 213
# Data(num_nodes=97, edge_index=[2, 3392], x=[97, 4], y=[97], edge_weight=[3392])
# Data(num_nodes=98, edge_index=[2, 3496], x=[98, 4], y=[98], edge_weight=[3496])
# Data(num_nodes=99, edge_index=[2, 3830], x=[99, 4], y=[99], edge_weight=[3830])
# Data(num_nodes=99, edge_index=[2, 3670], x=[99, 4], y=[99], edge_weight=[3670])
# Data(num_nodes=94, edge_index=[2, 3398], x=[94, 4], y=[94], edge_weight=[3398])
# Data(num_nodes=97, edge_index=[2, 3602], x=[97, 4], y=[97], edge_weight=[3602])
# outer batch 214
# Data(num_nodes=99, edge_index=[2, 3988], x=[99, 4], y=[99], edge_weight=[3988])
# Data(num_nodes=97, edge_index=[2, 4126], x=[97, 4], y=[97], edge_weight=[4126])
# Data(num_nodes=99, edge_index=[2, 4132], x=[99, 4], y=[99], edge_weight=[4132])
# Data(num_nodes=98, edge_index=[2, 4408], x=[98, 4], y=[98], edge_weight=[4408])
# Data(num_nodes=100, edge_index=[2, 4236], x=[100, 4], y=[100], edge_weight=[4236])
# Data(num_nodes=98, edge_index=[2, 3804], x=[98, 4], y=[98], edge_weight=[3804])
# outer batch 215
# Data(num_nodes=100, edge_index=[2, 3618], x=[100, 4], y=[100], edge_weight=[3618])
# Data(num_nodes=99, edge_index=[2, 3466], x=[99, 4], y=[99], edge_weight=[3466])
# Data(num_nodes=97, edge_index=[2, 3284], x=[97, 4], y=[97], edge_weight=[3284])
# Data(num_nodes=99, edge_index=[2, 3780], x=[99, 4], y=[99], edge_weight=[3780])
# Data(num_nodes=98, edge_index=[2, 3962], x=[98, 4], y=[98], edge_weight=[3962])
# Data(num_nodes=97, edge_index=[2, 3936], x=[97, 4], y=[97], edge_weight=[3936])
# outer batch 216
# Data(num_nodes=96, edge_index=[2, 3350], x=[96, 4], y=[96], edge_weight=[3350])
# Data(num_nodes=98, edge_index=[2, 3468], x=[98, 4], y=[98], edge_weight=[3468])
# Data(num_nodes=98, edge_index=[2, 3834], x=[98, 4], y=[98], edge_weight=[3834])
# Data(num_nodes=98, edge_index=[2, 3290], x=[98, 4], y=[98], edge_weight=[3290])
# Data(num_nodes=98, edge_index=[2, 3292], x=[98, 4], y=[98], edge_weight=[3292])
# Data(num_nodes=99, edge_index=[2, 4636], x=[99, 4], y=[99], edge_weight=[4636])
# outer batch 217
# Data(num_nodes=100, edge_index=[2, 3786], x=[100, 4], y=[100], edge_weight=[3786])
# Data(num_nodes=99, edge_index=[2, 3584], x=[99, 4], y=[99], edge_weight=[3584])
# Data(num_nodes=100, edge_index=[2, 3602], x=[100, 4], y=[100], edge_weight=[3602])
# Data(num_nodes=97, edge_index=[2, 3392], x=[97, 4], y=[97], edge_weight=[3392])
# Data(num_nodes=98, edge_index=[2, 3554], x=[98, 4], y=[98], edge_weight=[3554])
# Data(num_nodes=98, edge_index=[2, 4008], x=[98, 4], y=[98], edge_weight=[4008])
# outer batch 218
# Data(num_nodes=100, edge_index=[2, 3786], x=[100, 4], y=[100], edge_weight=[3786])
# Data(num_nodes=97, edge_index=[2, 3844], x=[97, 4], y=[97], edge_weight=[3844])
# Data(num_nodes=97, edge_index=[2, 3212], x=[97, 4], y=[97], edge_weight=[3212])
# Data(num_nodes=100, edge_index=[2, 3770], x=[100, 4], y=[100], edge_weight=[3770])
# Data(num_nodes=97, edge_index=[2, 3824], x=[97, 4], y=[97], edge_weight=[3824])
# Data(num_nodes=99, edge_index=[2, 3914], x=[99, 4], y=[99], edge_weight=[3914])

# %% [markdown]
# #### For validation set

# %%
# loop over the number of samples
num_samples = data['val']['data'].shape[0]
for i in range(num_samples):
    print(f"outer batch {i}")
    # Create a torch geometric data over each graph 
    outer_batch = Data(x = torch.tensor(data['val']['data'][i]), y = torch.tensor(data['val']['labels'][i].squeeze()),
                       edge_index=edge_index, edge_weight = edge_weight) 
    
    loader = GraphSAINTNodeSampler(outer_batch, batch_size=200, num_steps=6)
    for inner_batch in loader:
        print(inner_batch)
# Out:
# outer batch 0
# Data(num_nodes=192, edge_index=[2, 14460], x=[192, 4], y=[192], edge_weight=[14460])
# Data(num_nodes=188, edge_index=[2, 13672], x=[188, 4], y=[188], edge_weight=[13672])
# Data(num_nodes=191, edge_index=[2, 14078], x=[191, 4], y=[191], edge_weight=[14078])
# Data(num_nodes=186, edge_index=[2, 13702], x=[186, 4], y=[186], edge_weight=[13702])
# Data(num_nodes=186, edge_index=[2, 13888], x=[186, 4], y=[186], edge_weight=[13888])
# Data(num_nodes=189, edge_index=[2, 13502], x=[189, 4], y=[189], edge_weight=[13502])
# outer batch 1
# Data(num_nodes=191, edge_index=[2, 15550], x=[191, 4], y=[191], edge_weight=[15550])
# Data(num_nodes=188, edge_index=[2, 12806], x=[188, 4], y=[188], edge_weight=[12806])
# Data(num_nodes=190, edge_index=[2, 14140], x=[190, 4], y=[190], edge_weight=[14140])
# Data(num_nodes=189, edge_index=[2, 12802], x=[189, 4], y=[189], edge_weight=[12802])
# Data(num_nodes=190, edge_index=[2, 14058], x=[190, 4], y=[190], edge_weight=[14058])
# Data(num_nodes=191, edge_index=[2, 12998], x=[191, 4], y=[191], edge_weight=[12998])
# outer batch 2
# Data(num_nodes=195, edge_index=[2, 14238], x=[195, 4], y=[195], edge_weight=[14238])
# Data(num_nodes=192, edge_index=[2, 14356], x=[192, 4], y=[192], edge_weight=[14356])
# Data(num_nodes=192, edge_index=[2, 15476], x=[192, 4], y=[192], edge_weight=[15476])
# Data(num_nodes=197, edge_index=[2, 15270], x=[197, 4], y=[197], edge_weight=[15270])
# Data(num_nodes=189, edge_index=[2, 14964], x=[189, 4], y=[189], edge_weight=[14964])
# Data(num_nodes=184, edge_index=[2, 13074], x=[184, 4], y=[184], edge_weight=[13074])
# outer batch 3
# Data(num_nodes=193, edge_index=[2, 13796], x=[193, 4], y=[193], edge_weight=[13796])
# Data(num_nodes=187, edge_index=[2, 12752], x=[187, 4], y=[187], edge_weight=[12752])
# Data(num_nodes=190, edge_index=[2, 15700], x=[190, 4], y=[190], edge_weight=[15700])
# Data(num_nodes=194, edge_index=[2, 14426], x=[194, 4], y=[194], edge_weight=[14426])
# Data(num_nodes=190, edge_index=[2, 15004], x=[190, 4], y=[190], edge_weight=[15004])
# Data(num_nodes=189, edge_index=[2, 14060], x=[189, 4], y=[189], edge_weight=[14060])
# outer batch 4
# Data(num_nodes=195, edge_index=[2, 14748], x=[195, 4], y=[195], edge_weight=[14748])
# Data(num_nodes=184, edge_index=[2, 13486], x=[184, 4], y=[184], edge_weight=[13486])
# Data(num_nodes=189, edge_index=[2, 14308], x=[189, 4], y=[189], edge_weight=[14308])
# Data(num_nodes=193, edge_index=[2, 14412], x=[193, 4], y=[193], edge_weight=[14412])
# Data(num_nodes=197, edge_index=[2, 15298], x=[197, 4], y=[197], edge_weight=[15298])
# Data(num_nodes=191, edge_index=[2, 14648], x=[191, 4], y=[191], edge_weight=[14648])
# outer batch 5
# Data(num_nodes=191, edge_index=[2, 14248], x=[191, 4], y=[191], edge_weight=[14248])
# Data(num_nodes=182, edge_index=[2, 12720], x=[182, 4], y=[182], edge_weight=[12720])
# Data(num_nodes=191, edge_index=[2, 14908], x=[191, 4], y=[191], edge_weight=[14908])
# Data(num_nodes=190, edge_index=[2, 14194], x=[190, 4], y=[190], edge_weight=[14194])
# Data(num_nodes=189, edge_index=[2, 13292], x=[189, 4], y=[189], edge_weight=[13292])
# Data(num_nodes=191, edge_index=[2, 14410], x=[191, 4], y=[191], edge_weight=[14410])
# outer batch 6
# Data(num_nodes=190, edge_index=[2, 14836], x=[190, 4], y=[190], edge_weight=[14836])
# Data(num_nodes=196, edge_index=[2, 15512], x=[196, 4], y=[196], edge_weight=[15512])
# Data(num_nodes=191, edge_index=[2, 14034], x=[191, 4], y=[191], edge_weight=[14034])
# Data(num_nodes=196, edge_index=[2, 15264], x=[196, 4], y=[196], edge_weight=[15264])
# Data(num_nodes=190, edge_index=[2, 14360], x=[190, 4], y=[190], edge_weight=[14360])
# Data(num_nodes=187, edge_index=[2, 14276], x=[187, 4], y=[187], edge_weight=[14276])
# outer batch 7
# Data(num_nodes=189, edge_index=[2, 13786], x=[189, 4], y=[189], edge_weight=[13786])
# Data(num_nodes=191, edge_index=[2, 14146], x=[191, 4], y=[191], edge_weight=[14146])
# Data(num_nodes=192, edge_index=[2, 12888], x=[192, 4], y=[192], edge_weight=[12888])
# Data(num_nodes=191, edge_index=[2, 15566], x=[191, 4], y=[191], edge_weight=[15566])
# Data(num_nodes=189, edge_index=[2, 12554], x=[189, 4], y=[189], edge_weight=[12554])
# Data(num_nodes=196, edge_index=[2, 15164], x=[196, 4], y=[196], edge_weight=[15164])
# outer batch 8
# Data(num_nodes=190, edge_index=[2, 12606], x=[190, 4], y=[190], edge_weight=[12606])
# Data(num_nodes=194, edge_index=[2, 14804], x=[194, 4], y=[194], edge_weight=[14804])
# Data(num_nodes=195, edge_index=[2, 15468], x=[195, 4], y=[195], edge_weight=[15468])
# Data(num_nodes=194, edge_index=[2, 15714], x=[194, 4], y=[194], edge_weight=[15714])
# Data(num_nodes=193, edge_index=[2, 13544], x=[193, 4], y=[193], edge_weight=[13544])
# Data(num_nodes=189, edge_index=[2, 13520], x=[189, 4], y=[189], edge_weight=[13520])
# outer batch 9
# Data(num_nodes=194, edge_index=[2, 13984], x=[194, 4], y=[194], edge_weight=[13984])
# Data(num_nodes=194, edge_index=[2, 14282], x=[194, 4], y=[194], edge_weight=[14282])
# Data(num_nodes=192, edge_index=[2, 14430], x=[192, 4], y=[192], edge_weight=[14430])
# Data(num_nodes=184, edge_index=[2, 13770], x=[184, 4], y=[184], edge_weight=[13770])
# Data(num_nodes=193, edge_index=[2, 13904], x=[193, 4], y=[193], edge_weight=[13904])
# Data(num_nodes=190, edge_index=[2, 12368], x=[190, 4], y=[190], edge_weight=[12368])
# outer batch 10
# Data(num_nodes=194, edge_index=[2, 15282], x=[194, 4], y=[194], edge_weight=[15282])
# Data(num_nodes=189, edge_index=[2, 15692], x=[189, 4], y=[189], edge_weight=[15692])
# Data(num_nodes=189, edge_index=[2, 14876], x=[189, 4], y=[189], edge_weight=[14876])
# Data(num_nodes=187, edge_index=[2, 14232], x=[187, 4], y=[187], edge_weight=[14232])
# Data(num_nodes=193, edge_index=[2, 14974], x=[193, 4], y=[193], edge_weight=[14974])
# Data(num_nodes=191, edge_index=[2, 14536], x=[191, 4], y=[191], edge_weight=[14536])
# outer batch 11
# Data(num_nodes=190, edge_index=[2, 14484], x=[190, 4], y=[190], edge_weight=[14484])
# Data(num_nodes=192, edge_index=[2, 13538], x=[192, 4], y=[192], edge_weight=[13538])
# Data(num_nodes=187, edge_index=[2, 13240], x=[187, 4], y=[187], edge_weight=[13240])
# Data(num_nodes=190, edge_index=[2, 13600], x=[190, 4], y=[190], edge_weight=[13600])
# Data(num_nodes=194, edge_index=[2, 13332], x=[194, 4], y=[194], edge_weight=[13332])
# Data(num_nodes=189, edge_index=[2, 13554], x=[189, 4], y=[189], edge_weight=[13554])
# outer batch 12
# Data(num_nodes=193, edge_index=[2, 15312], x=[193, 4], y=[193], edge_weight=[15312])
# Data(num_nodes=188, edge_index=[2, 12918], x=[188, 4], y=[188], edge_weight=[12918])
# Data(num_nodes=193, edge_index=[2, 14848], x=[193, 4], y=[193], edge_weight=[14848])
# Data(num_nodes=194, edge_index=[2, 14624], x=[194, 4], y=[194], edge_weight=[14624])
# Data(num_nodes=191, edge_index=[2, 14308], x=[191, 4], y=[191], edge_weight=[14308])
# Data(num_nodes=194, edge_index=[2, 15258], x=[194, 4], y=[194], edge_weight=[15258])
# outer batch 13
# Data(num_nodes=195, edge_index=[2, 15632], x=[195, 4], y=[195], edge_weight=[15632])
# Data(num_nodes=193, edge_index=[2, 14920], x=[193, 4], y=[193], edge_weight=[14920])
# Data(num_nodes=192, edge_index=[2, 14156], x=[192, 4], y=[192], edge_weight=[14156])
# Data(num_nodes=187, edge_index=[2, 14374], x=[187, 4], y=[187], edge_weight=[14374])
# Data(num_nodes=188, edge_index=[2, 12714], x=[188, 4], y=[188], edge_weight=[12714])
# Data(num_nodes=190, edge_index=[2, 14398], x=[190, 4], y=[190], edge_weight=[14398])
# outer batch 14
# Data(num_nodes=191, edge_index=[2, 14526], x=[191, 4], y=[191], edge_weight=[14526])
# Data(num_nodes=193, edge_index=[2, 15178], x=[193, 4], y=[193], edge_weight=[15178])
# Data(num_nodes=190, edge_index=[2, 13724], x=[190, 4], y=[190], edge_weight=[13724])
# Data(num_nodes=191, edge_index=[2, 14776], x=[191, 4], y=[191], edge_weight=[14776])
# Data(num_nodes=191, edge_index=[2, 14270], x=[191, 4], y=[191], edge_weight=[14270])
# Data(num_nodes=186, edge_index=[2, 12742], x=[186, 4], y=[186], edge_weight=[12742])
# outer batch 15
# Data(num_nodes=192, edge_index=[2, 14232], x=[192, 4], y=[192], edge_weight=[14232])
# Data(num_nodes=192, edge_index=[2, 14576], x=[192, 4], y=[192], edge_weight=[14576])
# Data(num_nodes=194, edge_index=[2, 13780], x=[194, 4], y=[194], edge_weight=[13780])
# Data(num_nodes=192, edge_index=[2, 13940], x=[192, 4], y=[192], edge_weight=[13940])
# Data(num_nodes=187, edge_index=[2, 14070], x=[187, 4], y=[187], edge_weight=[14070])
# Data(num_nodes=197, edge_index=[2, 15328], x=[197, 4], y=[197], edge_weight=[15328])
# outer batch 16
# Data(num_nodes=187, edge_index=[2, 13772], x=[187, 4], y=[187], edge_weight=[13772])
# Data(num_nodes=189, edge_index=[2, 13178], x=[189, 4], y=[189], edge_weight=[13178])
# Data(num_nodes=190, edge_index=[2, 13634], x=[190, 4], y=[190], edge_weight=[13634])
# Data(num_nodes=188, edge_index=[2, 12868], x=[188, 4], y=[188], edge_weight=[12868])
# Data(num_nodes=188, edge_index=[2, 13516], x=[188, 4], y=[188], edge_weight=[13516])
# Data(num_nodes=188, edge_index=[2, 13376], x=[188, 4], y=[188], edge_weight=[13376])
# outer batch 17
# Data(num_nodes=191, edge_index=[2, 13466], x=[191, 4], y=[191], edge_weight=[13466])
# Data(num_nodes=191, edge_index=[2, 13988], x=[191, 4], y=[191], edge_weight=[13988])
# Data(num_nodes=193, edge_index=[2, 16226], x=[193, 4], y=[193], edge_weight=[16226])
# Data(num_nodes=189, edge_index=[2, 12650], x=[189, 4], y=[189], edge_weight=[12650])
# Data(num_nodes=186, edge_index=[2, 13806], x=[186, 4], y=[186], edge_weight=[13806])
# Data(num_nodes=194, edge_index=[2, 14362], x=[194, 4], y=[194], edge_weight=[14362])
# outer batch 18
# Data(num_nodes=194, edge_index=[2, 14112], x=[194, 4], y=[194], edge_weight=[14112])
# Data(num_nodes=191, edge_index=[2, 15326], x=[191, 4], y=[191], edge_weight=[15326])
# Data(num_nodes=190, edge_index=[2, 13742], x=[190, 4], y=[190], edge_weight=[13742])
# Data(num_nodes=186, edge_index=[2, 14012], x=[186, 4], y=[186], edge_weight=[14012])
# Data(num_nodes=192, edge_index=[2, 12562], x=[192, 4], y=[192], edge_weight=[12562])
# Data(num_nodes=192, edge_index=[2, 12776], x=[192, 4], y=[192], edge_weight=[12776])
# outer batch 19
# Data(num_nodes=196, edge_index=[2, 14788], x=[196, 4], y=[196], edge_weight=[14788])
# Data(num_nodes=193, edge_index=[2, 13494], x=[193, 4], y=[193], edge_weight=[13494])
# Data(num_nodes=190, edge_index=[2, 14166], x=[190, 4], y=[190], edge_weight=[14166])
# Data(num_nodes=181, edge_index=[2, 12568], x=[181, 4], y=[181], edge_weight=[12568])
# Data(num_nodes=191, edge_index=[2, 13670], x=[191, 4], y=[191], edge_weight=[13670])
# Data(num_nodes=192, edge_index=[2, 16326], x=[192, 4], y=[192], edge_weight=[16326])
# outer batch 20
# Data(num_nodes=192, edge_index=[2, 13678], x=[192, 4], y=[192], edge_weight=[13678])
# Data(num_nodes=187, edge_index=[2, 13776], x=[187, 4], y=[187], edge_weight=[13776])
# Data(num_nodes=190, edge_index=[2, 14564], x=[190, 4], y=[190], edge_weight=[14564])
# Data(num_nodes=190, edge_index=[2, 13598], x=[190, 4], y=[190], edge_weight=[13598])
# Data(num_nodes=189, edge_index=[2, 14866], x=[189, 4], y=[189], edge_weight=[14866])
# Data(num_nodes=190, edge_index=[2, 14916], x=[190, 4], y=[190], edge_weight=[14916])
# outer batch 21
# Data(num_nodes=188, edge_index=[2, 11926], x=[188, 4], y=[188], edge_weight=[11926])
# Data(num_nodes=192, edge_index=[2, 16984], x=[192, 4], y=[192], edge_weight=[16984])
# Data(num_nodes=189, edge_index=[2, 14318], x=[189, 4], y=[189], edge_weight=[14318])
# Data(num_nodes=190, edge_index=[2, 14544], x=[190, 4], y=[190], edge_weight=[14544])
# Data(num_nodes=192, edge_index=[2, 13622], x=[192, 4], y=[192], edge_weight=[13622])
# Data(num_nodes=191, edge_index=[2, 14390], x=[191, 4], y=[191], edge_weight=[14390])
# outer batch 22
# Data(num_nodes=196, edge_index=[2, 14294], x=[196, 4], y=[196], edge_weight=[14294])
# Data(num_nodes=193, edge_index=[2, 13478], x=[193, 4], y=[193], edge_weight=[13478])
# Data(num_nodes=191, edge_index=[2, 14748], x=[191, 4], y=[191], edge_weight=[14748])
# Data(num_nodes=185, edge_index=[2, 12326], x=[185, 4], y=[185], edge_weight=[12326])
# Data(num_nodes=193, edge_index=[2, 14066], x=[193, 4], y=[193], edge_weight=[14066])
# Data(num_nodes=186, edge_index=[2, 13212], x=[186, 4], y=[186], edge_weight=[13212])
# outer batch 23
# Data(num_nodes=186, edge_index=[2, 14054], x=[186, 4], y=[186], edge_weight=[14054])
# Data(num_nodes=190, edge_index=[2, 13594], x=[190, 4], y=[190], edge_weight=[13594])
# Data(num_nodes=192, edge_index=[2, 14532], x=[192, 4], y=[192], edge_weight=[14532])
# Data(num_nodes=196, edge_index=[2, 14606], x=[196, 4], y=[196], edge_weight=[14606])
# Data(num_nodes=193, edge_index=[2, 14886], x=[193, 4], y=[193], edge_weight=[14886])
# Data(num_nodes=190, edge_index=[2, 14220], x=[190, 4], y=[190], edge_weight=[14220])

# %% [markdown]
# #### For testing set

# %%
# loop over the number of samples
num_samples = data['tst']['data'].shape[0]
for i in range(num_samples):
    print(f"outer batch {i}")
    # Create a torch geometric data over each graph 
    outer_batch = Data(x = torch.tensor(data['tst']['data'][i]), y = torch.tensor(data['tst']['labels'][i].squeeze()),
                       edge_index=edge_index, edge_weight = edge_weight) 
    
    loader = GraphSAINTNodeSampler(outer_batch, batch_size=200, num_steps=6)
    for inner_batch in loader:
        print(inner_batch)
# Out:
# outer batch 0
# Data(num_nodes=190, edge_index=[2, 13594], x=[190, 4], y=[190], edge_weight=[13594])
# Data(num_nodes=188, edge_index=[2, 13100], x=[188, 4], y=[188], edge_weight=[13100])
# Data(num_nodes=189, edge_index=[2, 13744], x=[189, 4], y=[189], edge_weight=[13744])
# Data(num_nodes=190, edge_index=[2, 15088], x=[190, 4], y=[190], edge_weight=[15088])
# Data(num_nodes=191, edge_index=[2, 15136], x=[191, 4], y=[191], edge_weight=[15136])
# Data(num_nodes=190, edge_index=[2, 13934], x=[190, 4], y=[190], edge_weight=[13934])
# outer batch 1
# Data(num_nodes=189, edge_index=[2, 14842], x=[189, 4], y=[189], edge_weight=[14842])
# Data(num_nodes=194, edge_index=[2, 15216], x=[194, 4], y=[194], edge_weight=[15216])
# Data(num_nodes=194, edge_index=[2, 14150], x=[194, 4], y=[194], edge_weight=[14150])
# Data(num_nodes=185, edge_index=[2, 14472], x=[185, 4], y=[185], edge_weight=[14472])
# Data(num_nodes=190, edge_index=[2, 15480], x=[190, 4], y=[190], edge_weight=[15480])
# Data(num_nodes=189, edge_index=[2, 13210], x=[189, 4], y=[189], edge_weight=[13210])
# outer batch 2
# Data(num_nodes=188, edge_index=[2, 12780], x=[188, 4], y=[188], edge_weight=[12780])
# Data(num_nodes=192, edge_index=[2, 15734], x=[192, 4], y=[192], edge_weight=[15734])
# Data(num_nodes=186, edge_index=[2, 12750], x=[186, 4], y=[186], edge_weight=[12750])
# Data(num_nodes=192, edge_index=[2, 15046], x=[192, 4], y=[192], edge_weight=[15046])
# Data(num_nodes=186, edge_index=[2, 13986], x=[186, 4], y=[186], edge_weight=[13986])
# Data(num_nodes=196, edge_index=[2, 15816], x=[196, 4], y=[196], edge_weight=[15816])
# outer batch 3
# Data(num_nodes=191, edge_index=[2, 12718], x=[191, 4], y=[191], edge_weight=[12718])
# Data(num_nodes=192, edge_index=[2, 14440], x=[192, 4], y=[192], edge_weight=[14440])
# Data(num_nodes=198, edge_index=[2, 14886], x=[198, 4], y=[198], edge_weight=[14886])
# Data(num_nodes=190, edge_index=[2, 14772], x=[190, 4], y=[190], edge_weight=[14772])
# Data(num_nodes=195, edge_index=[2, 15614], x=[195, 4], y=[195], edge_weight=[15614])
# Data(num_nodes=188, edge_index=[2, 15494], x=[188, 4], y=[188], edge_weight=[15494])
# outer batch 4
# Data(num_nodes=197, edge_index=[2, 12948], x=[197, 4], y=[197], edge_weight=[12948])
# Data(num_nodes=191, edge_index=[2, 14584], x=[191, 4], y=[191], edge_weight=[14584])
# Data(num_nodes=181, edge_index=[2, 13122], x=[181, 4], y=[181], edge_weight=[13122])
# Data(num_nodes=189, edge_index=[2, 14088], x=[189, 4], y=[189], edge_weight=[14088])
# Data(num_nodes=195, edge_index=[2, 13650], x=[195, 4], y=[195], edge_weight=[13650])
# Data(num_nodes=192, edge_index=[2, 15280], x=[192, 4], y=[192], edge_weight=[15280])
# outer batch 5
# Data(num_nodes=190, edge_index=[2, 15712], x=[190, 4], y=[190], edge_weight=[15712])
# Data(num_nodes=194, edge_index=[2, 14886], x=[194, 4], y=[194], edge_weight=[14886])
# Data(num_nodes=195, edge_index=[2, 14294], x=[195, 4], y=[195], edge_weight=[14294])
# Data(num_nodes=190, edge_index=[2, 13288], x=[190, 4], y=[190], edge_weight=[13288])
# Data(num_nodes=193, edge_index=[2, 14350], x=[193, 4], y=[193], edge_weight=[14350])
# Data(num_nodes=193, edge_index=[2, 13236], x=[193, 4], y=[193], edge_weight=[13236])
# outer batch 6
# Data(num_nodes=195, edge_index=[2, 14894], x=[195, 4], y=[195], edge_weight=[14894])
# Data(num_nodes=193, edge_index=[2, 15008], x=[193, 4], y=[193], edge_weight=[15008])
# Data(num_nodes=191, edge_index=[2, 13136], x=[191, 4], y=[191], edge_weight=[13136])
# Data(num_nodes=190, edge_index=[2, 13228], x=[190, 4], y=[190], edge_weight=[13228])
# Data(num_nodes=194, edge_index=[2, 14432], x=[194, 4], y=[194], edge_weight=[14432])
# Data(num_nodes=191, edge_index=[2, 15626], x=[191, 4], y=[191], edge_weight=[15626])
# outer batch 7
# Data(num_nodes=194, edge_index=[2, 15864], x=[194, 4], y=[194], edge_weight=[15864])
# Data(num_nodes=191, edge_index=[2, 13994], x=[191, 4], y=[191], edge_weight=[13994])
# Data(num_nodes=190, edge_index=[2, 12420], x=[190, 4], y=[190], edge_weight=[12420])
# Data(num_nodes=187, edge_index=[2, 13506], x=[187, 4], y=[187], edge_weight=[13506])
# Data(num_nodes=188, edge_index=[2, 13704], x=[188, 4], y=[188], edge_weight=[13704])
# Data(num_nodes=188, edge_index=[2, 13668], x=[188, 4], y=[188], edge_weight=[13668])
# outer batch 8
# Data(num_nodes=189, edge_index=[2, 13880], x=[189, 4], y=[189], edge_weight=[13880])
# Data(num_nodes=191, edge_index=[2, 13252], x=[191, 4], y=[191], edge_weight=[13252])
# Data(num_nodes=193, edge_index=[2, 15290], x=[193, 4], y=[193], edge_weight=[15290])
# Data(num_nodes=191, edge_index=[2, 13226], x=[191, 4], y=[191], edge_weight=[13226])
# Data(num_nodes=187, edge_index=[2, 14688], x=[187, 4], y=[187], edge_weight=[14688])
# Data(num_nodes=194, edge_index=[2, 14414], x=[194, 4], y=[194], edge_weight=[14414])
# outer batch 9
# Data(num_nodes=197, edge_index=[2, 14634], x=[197, 4], y=[197], edge_weight=[14634])
# Data(num_nodes=196, edge_index=[2, 17646], x=[196, 4], y=[196], edge_weight=[17646])
# Data(num_nodes=189, edge_index=[2, 14004], x=[189, 4], y=[189], edge_weight=[14004])
# Data(num_nodes=188, edge_index=[2, 13952], x=[188, 4], y=[188], edge_weight=[13952])
# Data(num_nodes=192, edge_index=[2, 15254], x=[192, 4], y=[192], edge_weight=[15254])
# Data(num_nodes=185, edge_index=[2, 12556], x=[185, 4], y=[185], edge_weight=[12556])
# outer batch 10
# Data(num_nodes=189, edge_index=[2, 13784], x=[189, 4], y=[189], edge_weight=[13784])
# Data(num_nodes=196, edge_index=[2, 16950], x=[196, 4], y=[196], edge_weight=[16950])
# Data(num_nodes=194, edge_index=[2, 15076], x=[194, 4], y=[194], edge_weight=[15076])
# Data(num_nodes=191, edge_index=[2, 14416], x=[191, 4], y=[191], edge_weight=[14416])
# Data(num_nodes=187, edge_index=[2, 12886], x=[187, 4], y=[187], edge_weight=[12886])
# Data(num_nodes=191, edge_index=[2, 14186], x=[191, 4], y=[191], edge_weight=[14186])
# outer batch 11
# Data(num_nodes=193, edge_index=[2, 14804], x=[193, 4], y=[193], edge_weight=[14804])
# Data(num_nodes=192, edge_index=[2, 15608], x=[192, 4], y=[192], edge_weight=[15608])
# Data(num_nodes=195, edge_index=[2, 15990], x=[195, 4], y=[195], edge_weight=[15990])
# Data(num_nodes=194, edge_index=[2, 13798], x=[194, 4], y=[194], edge_weight=[13798])
# Data(num_nodes=188, edge_index=[2, 14130], x=[188, 4], y=[188], edge_weight=[14130])
# Data(num_nodes=194, edge_index=[2, 13778], x=[194, 4], y=[194], edge_weight=[13778])
# outer batch 12
# Data(num_nodes=189, edge_index=[2, 13124], x=[189, 4], y=[189], edge_weight=[13124])
# Data(num_nodes=189, edge_index=[2, 12652], x=[189, 4], y=[189], edge_weight=[12652])
# Data(num_nodes=193, edge_index=[2, 15166], x=[193, 4], y=[193], edge_weight=[15166])
# Data(num_nodes=190, edge_index=[2, 12256], x=[190, 4], y=[190], edge_weight=[12256])
# Data(num_nodes=192, edge_index=[2, 14800], x=[192, 4], y=[192], edge_weight=[14800])
# Data(num_nodes=191, edge_index=[2, 14408], x=[191, 4], y=[191], edge_weight=[14408])
# outer batch 13
# Data(num_nodes=190, edge_index=[2, 15396], x=[190, 4], y=[190], edge_weight=[15396])
# Data(num_nodes=188, edge_index=[2, 13730], x=[188, 4], y=[188], edge_weight=[13730])
# Data(num_nodes=194, edge_index=[2, 13898], x=[194, 4], y=[194], edge_weight=[13898])
# Data(num_nodes=194, edge_index=[2, 14474], x=[194, 4], y=[194], edge_weight=[14474])
# Data(num_nodes=194, edge_index=[2, 13512], x=[194, 4], y=[194], edge_weight=[13512])
# Data(num_nodes=195, edge_index=[2, 13938], x=[195, 4], y=[195], edge_weight=[13938])
# outer batch 14
# Data(num_nodes=187, edge_index=[2, 13860], x=[187, 4], y=[187], edge_weight=[13860])
# Data(num_nodes=191, edge_index=[2, 14174], x=[191, 4], y=[191], edge_weight=[14174])
# Data(num_nodes=186, edge_index=[2, 13130], x=[186, 4], y=[186], edge_weight=[13130])
# Data(num_nodes=191, edge_index=[2, 14944], x=[191, 4], y=[191], edge_weight=[14944])
# Data(num_nodes=192, edge_index=[2, 14260], x=[192, 4], y=[192], edge_weight=[14260])
# Data(num_nodes=191, edge_index=[2, 14748], x=[191, 4], y=[191], edge_weight=[14748])
# outer batch 15
# Data(num_nodes=196, edge_index=[2, 13300], x=[196, 4], y=[196], edge_weight=[13300])
# Data(num_nodes=190, edge_index=[2, 14432], x=[190, 4], y=[190], edge_weight=[14432])
# Data(num_nodes=190, edge_index=[2, 15066], x=[190, 4], y=[190], edge_weight=[15066])
# Data(num_nodes=185, edge_index=[2, 13996], x=[185, 4], y=[185], edge_weight=[13996])
# Data(num_nodes=194, edge_index=[2, 14176], x=[194, 4], y=[194], edge_weight=[14176])
# Data(num_nodes=196, edge_index=[2, 13842], x=[196, 4], y=[196], edge_weight=[13842])
# outer batch 16
# Data(num_nodes=192, edge_index=[2, 13896], x=[192, 4], y=[192], edge_weight=[13896])
# Data(num_nodes=194, edge_index=[2, 14604], x=[194, 4], y=[194], edge_weight=[14604])
# Data(num_nodes=191, edge_index=[2, 13048], x=[191, 4], y=[191], edge_weight=[13048])
# Data(num_nodes=186, edge_index=[2, 12862], x=[186, 4], y=[186], edge_weight=[12862])
# Data(num_nodes=182, edge_index=[2, 13018], x=[182, 4], y=[182], edge_weight=[13018])
# Data(num_nodes=190, edge_index=[2, 14106], x=[190, 4], y=[190], edge_weight=[14106])
# outer batch 17
# Data(num_nodes=196, edge_index=[2, 12470], x=[196, 4], y=[196], edge_weight=[12470])
# Data(num_nodes=189, edge_index=[2, 12990], x=[189, 4], y=[189], edge_weight=[12990])
# Data(num_nodes=186, edge_index=[2, 14532], x=[186, 4], y=[186], edge_weight=[14532])
# Data(num_nodes=189, edge_index=[2, 13476], x=[189, 4], y=[189], edge_weight=[13476])
# Data(num_nodes=193, edge_index=[2, 16850], x=[193, 4], y=[193], edge_weight=[16850])
# Data(num_nodes=184, edge_index=[2, 13202], x=[184, 4], y=[184], edge_weight=[13202])
# outer batch 18
# Data(num_nodes=192, edge_index=[2, 14482], x=[192, 4], y=[192], edge_weight=[14482])
# Data(num_nodes=191, edge_index=[2, 12600], x=[191, 4], y=[191], edge_weight=[12600])
# Data(num_nodes=187, edge_index=[2, 13366], x=[187, 4], y=[187], edge_weight=[13366])
# Data(num_nodes=191, edge_index=[2, 14054], x=[191, 4], y=[191], edge_weight=[14054])
# Data(num_nodes=185, edge_index=[2, 13976], x=[185, 4], y=[185], edge_weight=[13976])
# Data(num_nodes=191, edge_index=[2, 14384], x=[191, 4], y=[191], edge_weight=[14384])
# outer batch 19
# Data(num_nodes=193, edge_index=[2, 14698], x=[193, 4], y=[193], edge_weight=[14698])
# Data(num_nodes=193, edge_index=[2, 15462], x=[193, 4], y=[193], edge_weight=[15462])
# Data(num_nodes=183, edge_index=[2, 12008], x=[183, 4], y=[183], edge_weight=[12008])
# Data(num_nodes=193, edge_index=[2, 15608], x=[193, 4], y=[193], edge_weight=[15608])
# Data(num_nodes=194, edge_index=[2, 14000], x=[194, 4], y=[194], edge_weight=[14000])
# Data(num_nodes=191, edge_index=[2, 15412], x=[191, 4], y=[191], edge_weight=[15412])
# outer batch 20
# Data(num_nodes=189, edge_index=[2, 13514], x=[189, 4], y=[189], edge_weight=[13514])
# Data(num_nodes=196, edge_index=[2, 15186], x=[196, 4], y=[196], edge_weight=[15186])
# Data(num_nodes=191, edge_index=[2, 14140], x=[191, 4], y=[191], edge_weight=[14140])
# Data(num_nodes=193, edge_index=[2, 14806], x=[193, 4], y=[193], edge_weight=[14806])
# Data(num_nodes=195, edge_index=[2, 16416], x=[195, 4], y=[195], edge_weight=[16416])
# Data(num_nodes=192, edge_index=[2, 13274], x=[192, 4], y=[192], edge_weight=[13274])
# outer batch 21
# Data(num_nodes=188, edge_index=[2, 14424], x=[188, 4], y=[188], edge_weight=[14424])
# Data(num_nodes=191, edge_index=[2, 13336], x=[191, 4], y=[191], edge_weight=[13336])
# Data(num_nodes=193, edge_index=[2, 15560], x=[193, 4], y=[193], edge_weight=[15560])
# Data(num_nodes=188, edge_index=[2, 14682], x=[188, 4], y=[188], edge_weight=[14682])
# Data(num_nodes=190, edge_index=[2, 13250], x=[190, 4], y=[190], edge_weight=[13250])
# Data(num_nodes=191, edge_index=[2, 13656], x=[191, 4], y=[191], edge_weight=[13656])
# outer batch 22
# Data(num_nodes=188, edge_index=[2, 12936], x=[188, 4], y=[188], edge_weight=[12936])
# Data(num_nodes=186, edge_index=[2, 13640], x=[186, 4], y=[186], edge_weight=[13640])
# Data(num_nodes=189, edge_index=[2, 14420], x=[189, 4], y=[189], edge_weight=[14420])
# Data(num_nodes=189, edge_index=[2, 14962], x=[189, 4], y=[189], edge_weight=[14962])
# Data(num_nodes=193, edge_index=[2, 15620], x=[193, 4], y=[193], edge_weight=[15620])
# Data(num_nodes=188, edge_index=[2, 13662], x=[188, 4], y=[188], edge_weight=[13662])
# outer batch 23
# Data(num_nodes=185, edge_index=[2, 12612], x=[185, 4], y=[185], edge_weight=[12612])
# Data(num_nodes=195, edge_index=[2, 13654], x=[195, 4], y=[195], edge_weight=[13654])
# Data(num_nodes=194, edge_index=[2, 14694], x=[194, 4], y=[194], edge_weight=[14694])
# Data(num_nodes=192, edge_index=[2, 14452], x=[192, 4], y=[192], edge_weight=[14452])
# Data(num_nodes=192, edge_index=[2, 15258], x=[192, 4], y=[192], edge_weight=[15258])
# Data(num_nodes=191, edge_index=[2, 13314], x=[191, 4], y=[191], edge_weight=[13314])
